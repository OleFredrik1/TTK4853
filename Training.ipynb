# %% [markdown]
# #Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip3 list | grep scikit-learn
# Out:
# scikit-learn                  0.22.2.post1

# %%
# %cd /content/drive/MyDrive/Dataset
# Out:
# /content/drive/MyDrive/Dataset

# %%
# !ls
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# ls: cannot open directory '.': Transport endpoint is not connected

# %% [markdown]
# # TPU settings and packages

# %%
using_tpu = False

# %%
if using_tpu:
    # !curl https://raw.githubusercontent.com/pytorch/xla/master/contrib/scripts/env-setup.py -o pytorch-xla-env-setup.py
    # !python pytorch-xla-env-setup.py

# %% [markdown]
# # Imports

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms, utils
import matplotlib.pyplot as plt
import time
import os
import copy
import pandas as pd
import h5py
from skimage import io, transform
from torch.utils.data import Dataset, DataLoader
import random
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from multiprocessing import Process, Queue, Pool
import nibabel as nib
from tqdm import tqdm, trange
from sklearn.externals import joblib
from sklearn.model_selection import train_test_split
from skimage.transform import resize

if using_tpu:
    # imports the torch_xla package
    import torch_xla
    import torch_xla.core.xla_model as xm
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # Setting up TPU/GPU (if available)

# %%
if using_tpu:
    device = xm.xla_device()
else:
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Ensuring determinism (a.k.a. seeding the PRNG)

# %%
random.seed(123)

# %% [markdown]
# # Preparing the data

# %% [markdown]
# ## Setting up Kaggle API

# %%
# !pip3 install kaggle --user
# !mkdir /root/.kaggle
# !echo '{"username":"olefredrik","key":"0e5ab392a44e3df6cb6b5659f066569d"}' > /root/.kaggle/kaggle.json
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2020.12.5)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)

# %% [markdown]
# ## Downloading dataset

# %%
# !kaggle datasets download awsaf49/brats20-dataset-training-validation
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading brats20-dataset-training-validation.zip to /content/drive/MyDrive/Dataset
# 100% 4.16G/4.16G [01:22<00:00, 107MB/s]
# 100% 4.16G/4.16G [01:22<00:00, 54.0MB/s]

# %%
# !ls
# Out:
# brats20-dataset-training-validation.zip

# %% [markdown]
# ## Unpacking dataset

# %%
# !unzip -q brats20-dataset-training-validation.zip

# %% [markdown]
# ## Setting up DataLoader

# %%
class UnprocessedDataset(Dataset):
    def __init__(self, root_dir):
        self.files = os.listdir(root_dir)
        self.files = [file for file in self.files if file[-4:] != ".csv"]
        self.root_dir = root_dir
    
    def __len__(self):
        return len(self.files)
    
    def __get_file_path(self, idx, postfix):
        return self.root_dir + "/" + self.files[idx] + "/" + self.files[idx] + "_" + postfix + ".nii"
    
    def __getitem__(self, index):
        if type(index) == tuple:
            idx, s = index
        else:
            idx, s = index, slice(None, None)
        images = [nib.load(self.__get_file_path(idx, postfix)) for postfix in \
                  ["flair", "t1", "t2", "t1ce"]]
        images = np.array([np.asanyarray(image.dataobj) for image in images])
        images = np.swapaxes(images, 0, 3)
        images = images[s]
        y = np.array(nib.load(self.__get_file_path(idx, "seg")).dataobj)
        y = np.moveaxis(y, 2, 0)
        y = y[s]
        y = np.any(y, (0,1))
        return images, y

# %% [markdown]
# ## Dimentionality reduction and scaling

# %% [markdown]
# ### Choosing input data for PCA

# %%
training_data = UnprocessedDataset("./BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData")

# %%
random.seed(0)

X = []
for i in tqdm(random.choices(list(zip(range(len(training_data)), range(155))), k=200)):
    data = training_data[i][0]
    data = transform.resize(data, (224, 224, 3))
    X.append(data)

X = np.array(X)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
#
#
#   0%|          | 1/200 [00:01<05:27,  1.65s/it]
#
#
#   1%|          | 2/200 [00:02<04:46,  1.45s/it]
#
#
#   2%|▏         | 3/200 [00:06<07:24,  2.26s/it]
#
#
#   2%|▏         | 4/200 [00:11<09:37,  2.95s/it]
#
#
#   2%|▎         | 5/200 [00:15<11:08,  3.43s/it]
#
#
#   3%|▎         | 6/200 [00:20<11:56,  3.70s/it]
#
#
#   4%|▎         | 7/200 [00:24<12:26,  3.87s/it]
#
#
#   4%|▍         | 8/200 [00:28<12:04,  3.77s/it]
#
#
#   4%|▍         | 9/200 [00:32<12:29,  3.92s/it]
#
#
#   5%|▌         | 10/200 [00:36<12:51,  4.06s/it]
#
#
#   6%|▌         | 11/200 [00:42<14:00,  4.45s/it]
#
#
#   6%|▌         | 12/200 [00:46<13:43,  4.38s/it]
#
#
#   6%|▋         | 13/200 [00:50<13:49,  4.44s/it]
#
#
#   7%|▋         | 14/200 [00:51<09:57,  3.21s/it]
#
#
#   8%|▊         | 15/200 [00:55<10:43,  3.48s/it]
#
#
#   8%|▊         | 16/200 [01:00<12:03,  3.93s/it]
#
#
#   8%|▊         | 17/200 [01:04<12:41,  4.16s/it]
#
#
#   9%|▉         | 18/200 [01:10<13:30,  4.45s/it]
#
#
#  10%|▉         | 19/200 [01:14<13:02,  4.32s/it]
#
#
#  10%|█         | 20/200 [01:19<14:11,  4.73s/it]
#
#
#  10%|█         | 21/200 [01:24<13:44,  4.60s/it]
#
#
#  11%|█         | 22/200 [01:29<14:18,  4.82s/it]
#
#
#  12%|█▏        | 23/200 [01:29<10:15,  3.48s/it]
#
#
#  12%|█▏        | 24/200 [01:34<11:29,  3.92s/it]
#
#
#  12%|█▎        | 25/200 [01:35<08:41,  2.98s/it]
#
#
#  13%|█▎        | 26/200 [01:40<10:29,  3.62s/it]
#
#
#  14%|█▎        | 27/200 [01:46<12:06,  4.20s/it]
#
#
#  14%|█▍        | 28/200 [01:51<12:49,  4.47s/it]
#
#
#  14%|█▍        | 29/200 [01:51<09:19,  3.27s/it]
#
#
#  15%|█▌        | 30/200 [01:56<10:06,  3.57s/it]
#
#
#  16%|█▌        | 31/200 [01:56<07:24,  2.63s/it]
#
#
#  16%|█▌        | 32/200 [02:01<09:37,  3.44s/it]
#
#
#  16%|█▋        | 33/200 [02:03<07:54,  2.84s/it]
#
#
#  17%|█▋        | 34/200 [02:07<08:40,  3.14s/it]
#
#
#  18%|█▊        | 35/200 [02:11<09:58,  3.63s/it]
#
#
#  18%|█▊        | 36/200 [02:17<11:16,  4.13s/it]
#
#
#  18%|█▊        | 37/200 [02:21<11:49,  4.35s/it]
#
#
#  19%|█▉        | 38/200 [02:26<12:06,  4.49s/it]
#
#
#  20%|█▉        | 39/200 [02:30<11:36,  4.32s/it]
#
#
#  20%|██        | 40/200 [02:35<12:09,  4.56s/it]
#
#
#  20%|██        | 41/200 [02:40<12:03,  4.55s/it]
#
#
#  21%|██        | 42/200 [02:45<12:23,  4.71s/it]
#
#
#  22%|██▏       | 43/200 [02:45<08:54,  3.41s/it]
#
#
#  22%|██▏       | 44/200 [02:50<09:48,  3.77s/it]
#
#
#  22%|██▎       | 45/200 [02:54<09:57,  3.86s/it]
#
#
#  23%|██▎       | 46/200 [02:54<07:11,  2.80s/it]
#
#
#  24%|██▎       | 47/200 [02:59<08:37,  3.38s/it]
#
#
#  24%|██▍       | 48/200 [03:04<09:22,  3.70s/it]
#
#
#  24%|██▍       | 49/200 [03:08<09:55,  3.94s/it]
#
#
#  25%|██▌       | 50/200 [03:08<07:10,  2.87s/it]
#
#
#  26%|██▌       | 51/200 [03:09<05:15,  2.12s/it]
#
#
#  26%|██▌       | 52/200 [03:13<06:57,  2.82s/it]
#
#
#  26%|██▋       | 53/200 [03:18<08:11,  3.34s/it]
#
#
#  27%|██▋       | 54/200 [03:23<09:33,  3.92s/it]
#
#
#  28%|██▊       | 55/200 [03:23<06:53,  2.85s/it]
#
#
#  28%|██▊       | 56/200 [03:29<09:03,  3.78s/it]
#
#
#  28%|██▊       | 57/200 [03:34<09:44,  4.09s/it]
#
#
#  29%|██▉       | 58/200 [03:35<07:01,  2.97s/it]
#
#
#  30%|██▉       | 59/200 [03:40<08:44,  3.72s/it]
#
#
#  30%|███       | 60/200 [03:44<09:09,  3.93s/it]
#
#
#  30%|███       | 61/200 [03:49<09:35,  4.14s/it]
#
#
#  31%|███       | 62/200 [03:53<09:41,  4.21s/it]
#
#
#  32%|███▏      | 63/200 [03:54<06:58,  3.05s/it]
#
#
#  32%|███▏      | 64/200 [03:58<07:53,  3.48s/it]
#
#
#  32%|███▎      | 65/200 [04:04<09:04,  4.04s/it]
#
#
#  33%|███▎      | 66/200 [04:09<09:50,  4.41s/it]
#
#
#  34%|███▎      | 67/200 [04:14<10:32,  4.76s/it]
#
#
#  34%|███▍      | 68/200 [04:19<10:26,  4.74s/it]
#
#
#  34%|███▍      | 69/200 [04:24<10:33,  4.84s/it]
#
#
#  35%|███▌      | 70/200 [04:30<10:53,  5.03s/it]
#
#
#  36%|███▌      | 71/200 [04:30<07:48,  3.63s/it]
#
#
#  36%|███▌      | 72/200 [04:34<08:08,  3.82s/it]
#
#
#  36%|███▋      | 73/200 [04:35<05:54,  2.79s/it]
#
#
#  37%|███▋      | 74/200 [04:39<06:58,  3.32s/it]
#
#
#  38%|███▊      | 75/200 [04:40<05:03,  2.43s/it]
#
#
#  38%|███▊      | 76/200 [04:44<06:06,  2.96s/it]
#
#
#  38%|███▊      | 77/200 [04:44<04:28,  2.19s/it]
#
#
#  39%|███▉      | 78/200 [04:50<06:45,  3.33s/it]
#
#
#  40%|███▉      | 79/200 [04:55<07:43,  3.83s/it]
#
#
#  40%|████      | 80/200 [04:56<05:48,  2.90s/it]
#
#
#  40%|████      | 81/200 [04:56<04:14,  2.14s/it]
#
#
#  41%|████      | 82/200 [04:57<03:12,  1.63s/it]
#
#
#  42%|████▏     | 83/200 [04:57<02:25,  1.25s/it]
#
#
#  42%|████▏     | 84/200 [05:02<04:17,  2.22s/it]
#
#
#  42%|████▎     | 85/200 [05:02<03:10,  1.65s/it]
#
#
#  43%|████▎     | 86/200 [05:06<04:47,  2.52s/it]
#
#
#  44%|████▎     | 87/200 [05:08<04:16,  2.27s/it]
#
#
#  44%|████▍     | 88/200 [05:13<05:43,  3.07s/it]
#
#
#  44%|████▍     | 89/200 [05:18<06:57,  3.76s/it]
#
#
#  45%|████▌     | 90/200 [05:19<05:00,  2.74s/it]
#
#
#  46%|████▌     | 91/200 [05:24<06:25,  3.53s/it]
#
#
#  46%|████▌     | 92/200 [05:24<04:38,  2.58s/it]
#
#
#  46%|████▋     | 93/200 [05:25<03:24,  1.91s/it]
#
#
#  47%|████▋     | 94/200 [05:30<05:20,  3.02s/it]
#
#
#  48%|████▊     | 95/200 [05:35<05:56,  3.39s/it]
#
#
#  48%|████▊     | 96/200 [05:40<07:05,  4.09s/it]
#
#
#  48%|████▊     | 97/200 [05:45<07:08,  4.16s/it]
#
#
#  49%|████▉     | 98/200 [05:45<05:06,  3.01s/it]
#
#
#  50%|████▉     | 99/200 [05:45<03:44,  2.22s/it]
#
#
#  50%|█████     | 100/200 [05:50<04:37,  2.78s/it]
#
#
#  50%|█████     | 101/200 [05:54<05:39,  3.43s/it]
#
#
#  51%|█████     | 102/200 [05:55<04:06,  2.51s/it]
#
#
#  52%|█████▏    | 103/200 [05:56<03:33,  2.20s/it]
#
#
#  52%|█████▏    | 104/200 [06:00<04:10,  2.61s/it]
#
#
#  52%|█████▎    | 105/200 [06:04<04:43,  2.99s/it]
#
#
#  53%|█████▎    | 106/200 [06:07<04:43,  3.02s/it]
#
#
#  54%|█████▎    | 107/200 [06:12<05:28,  3.54s/it]
#
#
#  54%|█████▍    | 108/200 [06:16<05:57,  3.89s/it]
#
#
#  55%|█████▍    | 109/200 [06:17<04:34,  3.01s/it]
#
#
#  55%|█████▌    | 110/200 [06:19<03:47,  2.53s/it]
#
#
#  56%|█████▌    | 111/200 [06:23<04:45,  3.21s/it]
#
#
#  56%|█████▌    | 112/200 [06:28<05:26,  3.71s/it]
#
#
#  56%|█████▋    | 113/200 [06:33<05:51,  4.04s/it]
#
#
#  57%|█████▋    | 114/200 [06:38<06:08,  4.29s/it]
#
#
#  57%|█████▊    | 115/200 [06:38<04:24,  3.11s/it]
#
#
#  58%|█████▊    | 116/200 [06:44<05:23,  3.85s/it]
#
#
#  58%|█████▊    | 117/200 [06:49<05:48,  4.20s/it]
#
#
#  59%|█████▉    | 118/200 [06:53<05:42,  4.18s/it]
#
#
#  60%|█████▉    | 119/200 [06:58<06:02,  4.47s/it]
#
#
#  60%|██████    | 120/200 [07:00<04:50,  3.63s/it]
#
#
#  60%|██████    | 121/200 [07:00<03:28,  2.64s/it]
#
#
#  61%|██████    | 122/200 [07:01<02:31,  1.94s/it]
#
#
#  62%|██████▏   | 123/200 [07:05<03:28,  2.71s/it]
#
#
#  62%|██████▏   | 124/200 [07:09<04:02,  3.19s/it]
#
#
#  62%|██████▎   | 125/200 [07:13<04:19,  3.46s/it]
#
#
#  63%|██████▎   | 126/200 [07:17<04:26,  3.60s/it]
#
#
#  64%|██████▎   | 127/200 [07:22<04:47,  3.94s/it]
#
#
#  64%|██████▍   | 128/200 [07:24<03:54,  3.25s/it]
#
#
#  64%|██████▍   | 129/200 [07:27<03:56,  3.33s/it]
#
#
#  65%|██████▌   | 130/200 [07:31<03:55,  3.36s/it]
#
#
#  66%|██████▌   | 131/200 [07:31<02:50,  2.47s/it]
#
#
#  66%|██████▌   | 132/200 [07:36<03:31,  3.12s/it]
#
#
#  66%|██████▋   | 133/200 [07:36<02:32,  2.28s/it]
#
#
#  67%|██████▋   | 134/200 [07:38<02:14,  2.03s/it]
#
#
#  68%|██████▊   | 135/200 [07:38<01:38,  1.52s/it]
#
#
#  68%|██████▊   | 136/200 [07:38<01:14,  1.17s/it]
#
#
#  68%|██████▊   | 137/200 [07:39<00:58,  1.09it/s]
#
#
#  69%|██████▉   | 138/200 [07:43<02:03,  1.99s/it]
#
#
#  70%|██████▉   | 139/200 [07:47<02:35,  2.55s/it]
#
#
#  70%|███████   | 140/200 [07:51<03:04,  3.08s/it]
#
#
#  70%|███████   | 141/200 [07:52<02:13,  2.26s/it]
#
#
#  71%|███████   | 142/200 [07:56<02:42,  2.81s/it]
#
#
#  72%|███████▏  | 143/200 [07:56<01:57,  2.07s/it]
#
#
#  72%|███████▏  | 144/200 [08:00<02:34,  2.76s/it]
#
#
#  72%|███████▎  | 145/200 [08:05<03:03,  3.34s/it]
#
#
#  73%|███████▎  | 146/200 [08:09<03:09,  3.51s/it]
#
#
#  74%|███████▎  | 147/200 [08:09<02:15,  2.56s/it]
#
#
#  74%|███████▍  | 148/200 [08:14<02:39,  3.06s/it]
#
#
#  74%|███████▍  | 149/200 [08:15<02:15,  2.65s/it]
#
#
#  75%|███████▌  | 150/200 [08:20<02:37,  3.16s/it]
#
#
#  76%|███████▌  | 151/200 [08:24<02:59,  3.66s/it]
#
#
#  76%|███████▌  | 152/200 [08:25<02:08,  2.68s/it]
#
#
#  76%|███████▋  | 153/200 [08:29<02:31,  3.22s/it]
#
#
#  77%|███████▋  | 154/200 [08:30<01:48,  2.36s/it]
#
#
#  78%|███████▊  | 155/200 [08:31<01:36,  2.15s/it]
#
#
#  78%|███████▊  | 156/200 [08:35<01:54,  2.59s/it]
#
#
#  78%|███████▊  | 157/200 [08:36<01:37,  2.28s/it]
#
#
#  79%|███████▉  | 158/200 [08:40<01:49,  2.62s/it]
#
#
#  80%|███████▉  | 159/200 [08:41<01:33,  2.28s/it]
#
#
#  80%|████████  | 160/200 [08:42<01:07,  1.70s/it]
#
#
#  80%|████████  | 161/200 [08:42<00:50,  1.29s/it]
#
#
#  81%|████████  | 162/200 [08:45<01:07,  1.78s/it]
#
#
#  82%|████████▏ | 163/200 [08:47<01:04,  1.75s/it]
#
#
#  82%|████████▏ | 164/200 [08:47<00:47,  1.32s/it]
#
#
#  82%|████████▎ | 165/200 [08:49<00:49,  1.41s/it]
#
#
#  83%|████████▎ | 166/200 [08:49<00:37,  1.09s/it]
#
#
#  84%|████████▎ | 167/200 [08:49<00:28,  1.14it/s]
#
#
#  84%|████████▍ | 168/200 [08:50<00:22,  1.40it/s]
#
#
#  84%|████████▍ | 169/200 [08:54<00:54,  1.76s/it]
#
#
#  85%|████████▌ | 170/200 [08:59<01:22,  2.75s/it]
#
#
#  86%|████████▌ | 171/200 [09:04<01:38,  3.38s/it]
#
#
#  86%|████████▌ | 172/200 [09:08<01:42,  3.67s/it]
#
#
#  86%|████████▋ | 173/200 [09:10<01:23,  3.09s/it]
#
#
#  87%|████████▋ | 174/200 [09:11<01:07,  2.61s/it]
#
#
#  88%|████████▊ | 175/200 [09:12<00:48,  1.93s/it]
#
#
#  88%|████████▊ | 176/200 [09:13<00:44,  1.85s/it]
#
#
#  88%|████████▊ | 177/200 [09:14<00:32,  1.40s/it]
#
#
#  89%|████████▉ | 178/200 [09:18<00:51,  2.32s/it]
#
#
#  90%|████████▉ | 179/200 [09:18<00:36,  1.73s/it]
#
#
#  90%|█████████ | 180/200 [09:23<00:52,  2.63s/it]
#
#
#  90%|█████████ | 181/200 [09:25<00:44,  2.34s/it]
#
#
#  91%|█████████ | 182/200 [09:30<00:55,  3.07s/it]
#
#
#  92%|█████████▏| 183/200 [09:34<00:59,  3.50s/it]
#
#
#  92%|█████████▏| 184/200 [09:35<00:40,  2.56s/it]
#
#
#  92%|█████████▎| 185/200 [09:38<00:44,  2.96s/it]
#
#
#  93%|█████████▎| 186/200 [09:39<00:32,  2.35s/it]
#
#
#  94%|█████████▎| 187/200 [09:41<00:27,  2.09s/it]
#
#
#  94%|█████████▍| 188/200 [09:41<00:18,  1.57s/it]
#
#
#  94%|█████████▍| 189/200 [09:43<00:16,  1.53s/it]
#
#
#  95%|█████████▌| 190/200 [09:43<00:11,  1.17s/it]
#
#
#  96%|█████████▌| 191/200 [09:43<00:08,  1.09it/s]
#
#
#  96%|█████████▌| 192/200 [09:48<00:15,  1.95s/it]
#
#
#  96%|█████████▋| 193/200 [09:49<00:13,  1.86s/it]
#
#
#  97%|█████████▋| 194/200 [09:50<00:08,  1.43s/it]
#
#
#  98%|█████████▊| 195/200 [09:50<00:05,  1.10s/it]
#
#
#  98%|█████████▊| 196/200 [09:52<00:04,  1.21s/it]
#
#
#  98%|█████████▊| 197/200 [09:53<00:03,  1.33s/it]
#
#
#  99%|█████████▉| 198/200 [09:53<00:02,  1.03s/it]
#
#
# 100%|█████████▉| 199/200 [09:55<00:01,  1.22s/it]
#
#
# 100%|██████████| 200/200 [09:55<00:00,  2.98s/it]

# %%
X.shape
# Out:
# (200, 224, 224, 3)

# %% [markdown]
# ### Finding scale values

# %%
mean = np.mean(X, axis=(0, 1, 2))
std = np.std(X, axis=(0, 1, 2))
np.save("mean.npy", mean)
np.save("std.npy", std)
mean, std
# Out:
# (array([0.00126822, 0.00194388, 0.00209815]),
#  array([0.00302834, 0.00460108, 0.00478389]))

# %%
mean = np.load("mean.npy")
std = np.load("std.npy")

# %% [markdown]
# ## Creating test-validation split

# %%
np.random.seed(123)
train_index, test_index = train_test_split(list(range(len(training_data))), test_size=0.1)

# %%
# !ls
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: Transport endpoint is not connected
# ls: cannot open directory '.': Transport endpoint is not connected

# %% [markdown]
# ## Transforming the dataset

# %%
(i, j) = 302, 127
data, y = training_data[i]
datapoint = data[j]
datapoint = transform.resize(datapoint, (224, 224, 3))
datapoint = (datapoint - mean)/std
datapoint = np.moveaxis(datapoint, 2, 0)
datapoint = np.array([datapoint, y[j]], dtype=object)
np.save("./training_data/" + str(i) + "_" + str(j) + ".npy", datapoint)

# %%
# !mkdir training_data
for i in tqdm(train_index):
    data, y = training_data[i]
    for j in range(155):
        datapoint = data[j]
        datapoint = transform.resize(datapoint, (224, 224, 3))
        datapoint = (datapoint - mean)/std
        datapoint = np.moveaxis(datapoint, 2, 0)
        datapoint = np.array([datapoint, y[j]], dtype=object)
        np.save("./training_data/" + str(i) + "_" + str(j) + ".npy", datapoint)

# !mkdir test_data
for i in tqdm(test_index):
    data, y = training_data[i]
    for j in range(155):
        datapoint = data[j]
        datapoint = transform.resize(datapoint, (224, 224, 3))
        datapoint = (datapoint - mean)/std
        datapoint = np.moveaxis(datapoint, 2, 0)
        datapoint = np.array([datapoint, y[j]], dtype=object)
        np.save("./test_data/" + str(i) + "_" + str(j) + ".npy", datapoint)
# Out:
# mkdir: cannot create directory ‘training_data’: File exists
#   0%|          | 0/332 [00:00<?, ?it/s]
#
#
#   0%|          | 1/332 [00:07<41:23,  7.50s/it]
#
#
#   1%|          | 2/332 [00:15<41:47,  7.60s/it]
#
#
#   1%|          | 3/332 [00:23<42:01,  7.66s/it]
#
#
#   1%|          | 4/332 [00:35<49:03,  8.97s/it]
#
#
#   2%|▏         | 5/332 [00:46<52:22,  9.61s/it]
#
#
#   2%|▏         | 6/332 [01:03<1:04:15, 11.83s/it]
#
#
#   2%|▏         | 7/332 [01:14<1:03:33, 11.73s/it]
#
#
#   2%|▏         | 8/332 [01:26<1:03:35, 11.78s/it]
#
#
#   3%|▎         | 9/332 [01:35<58:57, 10.95s/it]
#
#
#   3%|▎         | 10/332 [01:42<52:40,  9.81s/it]
#
#
#   3%|▎         | 11/332 [01:55<57:00, 10.65s/it]
#
#
#   4%|▎         | 12/332 [02:06<57:52, 10.85s/it]
#
#
#   4%|▍         | 13/332 [02:17<58:04, 10.92s/it]
#
#
#   4%|▍         | 14/332 [02:28<57:52, 10.92s/it]
#
#
#   5%|▍         | 15/332 [02:36<52:03,  9.85s/it]
#
#
#   5%|▍         | 16/332 [02:43<47:24,  9.00s/it]
#
#
#   5%|▌         | 17/332 [02:54<51:08,  9.74s/it]
#
#
#   5%|▌         | 18/332 [03:06<53:41, 10.26s/it]
#
#
#   6%|▌         | 19/332 [03:17<55:09, 10.57s/it]
#
#
#   6%|▌         | 20/332 [03:30<58:08, 11.18s/it]
#
#
#   6%|▋         | 21/332 [03:37<52:57, 10.22s/it]
#
#
#   7%|▋         | 22/332 [03:49<54:03, 10.46s/it]
#
#
#   7%|▋         | 23/332 [03:59<53:57, 10.48s/it]
#
#
#   7%|▋         | 24/332 [04:08<51:08,  9.96s/it]
#
#
#   8%|▊         | 25/332 [04:19<52:33, 10.27s/it]
#
#
#   8%|▊         | 26/332 [04:30<53:24, 10.47s/it]
#
#
#   8%|▊         | 27/332 [04:41<54:37, 10.74s/it]
#
#
#   8%|▊         | 28/332 [04:49<49:47,  9.83s/it]
#
#
#   9%|▊         | 29/332 [04:57<47:17,  9.36s/it]
#
#
#   9%|▉         | 30/332 [05:05<44:25,  8.83s/it]
#
#
#   9%|▉         | 31/332 [05:13<43:36,  8.69s/it]
#
#
#  10%|▉         | 32/332 [05:23<46:05,  9.22s/it]
#
#
#  10%|▉         | 33/332 [05:34<48:33,  9.75s/it]
#
#
#  10%|█         | 34/332 [05:45<49:42, 10.01s/it]
#
#
#  11%|█         | 35/332 [05:57<51:45, 10.45s/it]
#
#
#  11%|█         | 36/332 [06:05<47:58,  9.72s/it]
#
#
#  11%|█         | 37/332 [06:16<50:32, 10.28s/it]
#
#
#  11%|█▏        | 38/332 [06:26<50:25, 10.29s/it]
#
#
#  12%|█▏        | 39/332 [06:34<46:45,  9.57s/it]
#
#
#  12%|█▏        | 40/332 [06:46<49:37, 10.20s/it]
#
#
#  12%|█▏        | 41/332 [06:57<50:21, 10.38s/it]
#
#
#  13%|█▎        | 42/332 [07:08<51:03, 10.56s/it]
#
#
#  13%|█▎        | 43/332 [07:20<52:56, 10.99s/it]
#
#
#  13%|█▎        | 44/332 [07:33<55:35, 11.58s/it]
#
#
#  14%|█▎        | 45/332 [07:45<55:46, 11.66s/it]
#
#
#  14%|█▍        | 46/332 [07:57<57:01, 11.96s/it]
#
#
#  14%|█▍        | 47/332 [08:09<55:56, 11.78s/it]
#
#
#  14%|█▍        | 48/332 [08:16<50:07, 10.59s/it]
#
#
#  15%|█▍        | 49/332 [08:27<50:35, 10.72s/it]
#
#
#  15%|█▌        | 50/332 [08:40<52:16, 11.12s/it]
#
#
#  15%|█▌        | 51/332 [08:47<47:33, 10.15s/it]
#
#
#  16%|█▌        | 52/332 [08:58<47:40, 10.22s/it]
#
#
#  16%|█▌        | 53/332 [09:08<46:48, 10.07s/it]
#
#
#  16%|█▋        | 54/332 [09:19<48:02, 10.37s/it]
#
#
#  17%|█▋        | 55/332 [09:31<50:13, 10.88s/it]
#
#
#  17%|█▋        | 56/332 [09:42<50:18, 10.94s/it]
#
#
#  17%|█▋        | 57/332 [09:51<48:17, 10.54s/it]
#
#
#  17%|█▋        | 58/332 [10:01<46:16, 10.13s/it]
#
#
#  18%|█▊        | 59/332 [10:12<47:57, 10.54s/it]
#
#
#  18%|█▊        | 60/332 [10:23<48:03, 10.60s/it]
#
#
#  18%|█▊        | 61/332 [10:35<49:33, 10.97s/it]
#
#
#  19%|█▊        | 62/332 [10:46<50:05, 11.13s/it]
#
#
#  19%|█▉        | 63/332 [10:58<50:36, 11.29s/it]
#
#
#  19%|█▉        | 64/332 [11:13<55:14, 12.37s/it]
#
#
#  20%|█▉        | 65/332 [11:25<54:52, 12.33s/it]
#
#
#  20%|█▉        | 66/332 [11:37<54:35, 12.31s/it]
#
#
#  20%|██        | 67/332 [11:49<53:27, 12.10s/it]
#
#
#  20%|██        | 68/332 [12:01<52:53, 12.02s/it]
#
#
#  21%|██        | 69/332 [12:12<52:12, 11.91s/it]
#
#
#  21%|██        | 70/332 [12:24<51:23, 11.77s/it]
#
#
#  21%|██▏       | 71/332 [12:35<50:37, 11.64s/it]
#
#
#  22%|██▏       | 72/332 [12:47<50:26, 11.64s/it]
#
#
#  22%|██▏       | 73/332 [13:00<52:19, 12.12s/it]
#
#
#  22%|██▏       | 74/332 [13:12<51:34, 12.00s/it]
#
#
#  23%|██▎       | 75/332 [13:23<50:40, 11.83s/it]
#
#
#  23%|██▎       | 76/332 [13:34<48:46, 11.43s/it]
#
#
#  23%|██▎       | 77/332 [13:45<48:20, 11.37s/it]
#
#
#  23%|██▎       | 78/332 [13:57<49:46, 11.76s/it]
#
#
#  24%|██▍       | 79/332 [14:10<50:35, 12.00s/it]
#
#
#  24%|██▍       | 80/332 [14:26<55:49, 13.29s/it]
#
#
#  24%|██▍       | 81/332 [14:38<53:09, 12.71s/it]
#
#
#  25%|██▍       | 82/332 [14:49<51:44, 12.42s/it]
#
#
#  25%|██▌       | 83/332 [15:01<50:22, 12.14s/it]
#
#
#  25%|██▌       | 84/332 [15:14<51:28, 12.46s/it]
#
#
#  26%|██▌       | 85/332 [15:26<50:04, 12.16s/it]
#
#
#  26%|██▌       | 86/332 [15:37<49:07, 11.98s/it]
#
#
#  26%|██▌       | 87/332 [15:54<54:23, 13.32s/it]
#
#
#  27%|██▋       | 88/332 [16:06<52:54, 13.01s/it]
#
#
#  27%|██▋       | 89/332 [16:19<52:18, 12.92s/it]
#
#
#  27%|██▋       | 90/332 [16:30<50:13, 12.45s/it]
#
#
#  27%|██▋       | 91/332 [16:41<48:53, 12.17s/it]
#
#
#  28%|██▊       | 92/332 [16:53<47:41, 11.92s/it]
#
#
#  28%|██▊       | 93/332 [17:05<47:46, 11.99s/it]
#
#
#  28%|██▊       | 94/332 [17:17<47:58, 12.09s/it]
#
#
#  29%|██▊       | 95/332 [17:29<47:52, 12.12s/it]
#
#
#  29%|██▉       | 96/332 [17:40<46:07, 11.73s/it]
#
#
#  29%|██▉       | 97/332 [17:52<45:58, 11.74s/it]
#
#
#  30%|██▉       | 98/332 [18:05<46:48, 12.00s/it]
#
#
#  30%|██▉       | 99/332 [18:17<47:16, 12.17s/it]
#
#
#  30%|███       | 100/332 [18:29<46:34, 12.05s/it]
#
#
#  30%|███       | 101/332 [18:44<49:34, 12.88s/it]
#
#
#  31%|███       | 102/332 [18:56<48:32, 12.66s/it]
#
#
#  31%|███       | 103/332 [19:07<47:03, 12.33s/it]
#
#
#  31%|███▏      | 104/332 [19:21<48:07, 12.67s/it]
#
#
#  32%|███▏      | 105/332 [19:33<47:19, 12.51s/it]
#
#
#  32%|███▏      | 106/332 [19:47<48:15, 12.81s/it]
#
#
#  32%|███▏      | 107/332 [19:59<47:38, 12.70s/it]
#
#
#  33%|███▎      | 108/332 [20:11<46:18, 12.40s/it]
#
#
#  33%|███▎      | 109/332 [20:24<46:30, 12.51s/it]
#
#
#  33%|███▎      | 110/332 [20:35<45:38, 12.33s/it]
#
#
#  33%|███▎      | 111/332 [20:48<45:31, 12.36s/it]
#
#
#  34%|███▎      | 112/332 [20:59<44:27, 12.13s/it]
#
#
#  34%|███▍      | 113/332 [21:15<47:51, 13.11s/it]
#
#
#  34%|███▍      | 114/332 [21:27<46:57, 12.92s/it]
#
#
#  35%|███▍      | 115/332 [21:38<44:47, 12.39s/it]
#
#
#  35%|███▍      | 116/332 [21:51<44:15, 12.30s/it]
#
#
#  35%|███▌      | 117/332 [22:04<44:53, 12.53s/it]
#
#
#  36%|███▌      | 118/332 [22:16<44:31, 12.48s/it]
#
#
#  36%|███▌      | 119/332 [22:27<42:42, 12.03s/it]
#
#
#  36%|███▌      | 120/332 [22:40<43:36, 12.34s/it]
#
#
#  36%|███▋      | 121/332 [22:52<42:44, 12.15s/it]
#
#
#  37%|███▋      | 122/332 [23:03<41:56, 11.98s/it]
#
#
#  37%|███▋      | 123/332 [23:17<43:15, 12.42s/it]
#
#
#  37%|███▋      | 124/332 [23:29<42:58, 12.40s/it]
#
#
#  38%|███▊      | 125/332 [23:42<43:39, 12.65s/it]
#
#
#  38%|███▊      | 126/332 [23:54<42:09, 12.28s/it]
#
#
#  38%|███▊      | 127/332 [24:05<41:10, 12.05s/it]
#
#
#  39%|███▊      | 128/332 [24:18<41:09, 12.11s/it]
#
#
#  39%|███▉      | 129/332 [24:29<40:39, 12.02s/it]
#
#
#  39%|███▉      | 130/332 [24:42<41:29, 12.33s/it]
#
#
#  39%|███▉      | 131/332 [24:55<41:43, 12.45s/it]
#
#
#  40%|███▉      | 132/332 [25:08<41:31, 12.46s/it]
#
#
#  40%|████      | 133/332 [25:20<41:20, 12.46s/it]
#
#
#  40%|████      | 134/332 [25:31<39:27, 11.96s/it]
#
#
#  41%|████      | 135/332 [25:43<39:43, 12.10s/it]
#
#
#  41%|████      | 136/332 [25:55<39:19, 12.04s/it]
#
#
#  41%|████▏     | 137/332 [26:07<39:04, 12.02s/it]
#
#
#  42%|████▏     | 138/332 [26:20<39:40, 12.27s/it]
#
#
#  42%|████▏     | 139/332 [26:33<39:55, 12.41s/it]
#
#
#  42%|████▏     | 140/332 [26:43<37:56, 11.86s/it]
#
#
#  42%|████▏     | 141/332 [26:54<36:40, 11.52s/it]
#
#
#  43%|████▎     | 142/332 [27:06<37:11, 11.75s/it]
#
#
#  43%|████▎     | 143/332 [27:17<36:15, 11.51s/it]
#
#
#  43%|████▎     | 144/332 [27:29<36:22, 11.61s/it]
#
#
#  44%|████▎     | 145/332 [27:40<35:51, 11.50s/it]
#
#
#  44%|████▍     | 146/332 [27:53<37:00, 11.94s/it]
#
#
#  44%|████▍     | 147/332 [28:05<36:36, 11.87s/it]
#
#
#  45%|████▍     | 148/332 [28:16<35:46, 11.67s/it]
#
#
#  45%|████▍     | 149/332 [28:28<35:29, 11.64s/it]
#
#
#  45%|████▌     | 150/332 [28:41<37:01, 12.20s/it]
#
#
#  45%|████▌     | 151/332 [28:52<35:33, 11.79s/it]
#
#
#  46%|████▌     | 152/332 [29:04<35:39, 11.89s/it]
#
#
#  46%|████▌     | 153/332 [29:16<35:16, 11.83s/it]
#
#
#  46%|████▋     | 154/332 [29:28<35:23, 11.93s/it]
#
#
#  47%|████▋     | 155/332 [29:42<36:32, 12.38s/it]
#
#
#  47%|████▋     | 156/332 [29:53<35:31, 12.11s/it]
#
#
#  47%|████▋     | 157/332 [30:05<35:13, 12.08s/it]
#
#
#  48%|████▊     | 158/332 [30:16<34:06, 11.76s/it]
#
#
#  48%|████▊     | 159/332 [30:28<33:39, 11.67s/it]
#
#
#  48%|████▊     | 160/332 [30:39<33:11, 11.58s/it]
#
#
#  48%|████▊     | 161/332 [30:53<34:46, 12.20s/it]
#
#
#  49%|████▉     | 162/332 [31:04<33:31, 11.83s/it]
#
#
#  49%|████▉     | 163/332 [31:17<34:55, 12.40s/it]
#
#
#  49%|████▉     | 164/332 [31:34<38:11, 13.64s/it]
#
#
#  50%|████▉     | 165/332 [31:45<36:11, 13.00s/it]
#
#
#  50%|█████     | 166/332 [31:58<35:38, 12.88s/it]
#
#
#  50%|█████     | 167/332 [32:10<35:09, 12.78s/it]
#
#
#  51%|█████     | 168/332 [32:21<33:24, 12.22s/it]
#
#
#  51%|█████     | 169/332 [32:35<34:03, 12.54s/it]
#
#
#  51%|█████     | 170/332 [32:46<33:00, 12.22s/it]
#
#
#  52%|█████▏    | 171/332 [33:00<34:19, 12.79s/it]
#
#
#  52%|█████▏    | 172/332 [33:11<32:45, 12.28s/it]
#
#
#  52%|█████▏    | 173/332 [33:24<32:52, 12.40s/it]
#
#
#  52%|█████▏    | 174/332 [33:37<33:06, 12.57s/it]
#
#
#  53%|█████▎    | 175/332 [33:48<31:44, 12.13s/it]
#
#
#  53%|█████▎    | 176/332 [33:59<30:42, 11.81s/it]
#
#
#  53%|█████▎    | 177/332 [34:10<30:04, 11.64s/it]
#
#
#  54%|█████▎    | 178/332 [34:22<30:00, 11.69s/it]
#
#
#  54%|█████▍    | 179/332 [34:34<29:55, 11.74s/it]
#
#
#  54%|█████▍    | 180/332 [34:45<29:07, 11.50s/it]
#
#
#  55%|█████▍    | 181/332 [34:57<29:11, 11.60s/it]
#
#
#  55%|█████▍    | 182/332 [35:08<28:35, 11.43s/it]
#
#
#  55%|█████▌    | 183/332 [35:21<29:41, 11.96s/it]
#
#
#  55%|█████▌    | 184/332 [35:33<29:35, 12.00s/it]
#
#
#  56%|█████▌    | 185/332 [35:45<29:09, 11.90s/it]
#
#
#  56%|█████▌    | 186/332 [35:58<29:42, 12.21s/it]
#
#
#  56%|█████▋    | 187/332 [36:09<29:01, 12.01s/it]
#
#
#  57%|█████▋    | 188/332 [36:22<29:07, 12.14s/it]
#
#
#  57%|█████▋    | 189/332 [36:34<29:21, 12.32s/it]
#
#
#  57%|█████▋    | 190/332 [36:47<29:02, 12.27s/it]
#
#
#  58%|█████▊    | 191/332 [36:58<28:09, 11.98s/it]
#
#
#  58%|█████▊    | 192/332 [37:10<28:09, 12.07s/it]
#
#
#  58%|█████▊    | 193/332 [37:22<27:43, 11.97s/it]
#
#
#  58%|█████▊    | 194/332 [37:34<27:37, 12.01s/it]
#
#
#  59%|█████▊    | 195/332 [37:45<26:23, 11.56s/it]
#
#
#  59%|█████▉    | 196/332 [37:56<26:00, 11.47s/it]
#
#
#  59%|█████▉    | 197/332 [38:07<25:53, 11.51s/it]
#
#
#  60%|█████▉    | 198/332 [38:19<25:48, 11.56s/it]
#
#
#  60%|█████▉    | 199/332 [38:31<25:31, 11.51s/it]
#
#
#  60%|██████    | 200/332 [38:43<25:43, 11.70s/it]
#
#
#  61%|██████    | 201/332 [38:56<26:22, 12.08s/it]
#
#
#  61%|██████    | 202/332 [39:09<26:47, 12.37s/it]
#
#
#  61%|██████    | 203/332 [39:21<26:22, 12.27s/it]
#
#
#  61%|██████▏   | 204/332 [39:34<26:47, 12.56s/it]
#
#
#  62%|██████▏   | 205/332 [39:47<26:46, 12.65s/it]
#
#
#  62%|██████▏   | 206/332 [40:00<27:08, 12.93s/it]
#
#
#  62%|██████▏   | 207/332 [40:12<25:52, 12.42s/it]
#
#
#  63%|██████▎   | 208/332 [40:23<25:10, 12.18s/it]
#
#
#  63%|██████▎   | 209/332 [40:36<25:27, 12.42s/it]
#
#
#  63%|██████▎   | 210/332 [40:48<25:07, 12.35s/it]
#
#
#  64%|██████▎   | 211/332 [41:01<25:02, 12.42s/it]
#
#
#  64%|██████▍   | 212/332 [41:14<25:16, 12.64s/it]
#
#
#  64%|██████▍   | 213/332 [41:26<24:27, 12.33s/it]
#
#
#  64%|██████▍   | 214/332 [41:41<25:46, 13.10s/it]
#
#
#  65%|██████▍   | 215/332 [41:54<25:55, 13.29s/it]
#
#
#  65%|██████▌   | 216/332 [42:06<24:56, 12.90s/it]
#
#
#  65%|██████▌   | 217/332 [42:20<25:08, 13.12s/it]
#
#
#  66%|██████▌   | 218/332 [42:33<24:47, 13.04s/it]
#
#
#  66%|██████▌   | 219/332 [42:45<23:48, 12.64s/it]
#
#
#  66%|██████▋   | 220/332 [42:56<23:04, 12.36s/it]
#
#
#  67%|██████▋   | 221/332 [43:09<22:48, 12.33s/it]
#
#
#  67%|██████▋   | 222/332 [43:20<22:03, 12.03s/it]
#
#
#  67%|██████▋   | 223/332 [43:32<21:38, 11.91s/it]
#
#
#  67%|██████▋   | 224/332 [43:44<21:56, 12.19s/it]
#
#
#  68%|██████▊   | 225/332 [43:57<21:47, 12.22s/it]
#
#
#  68%|██████▊   | 226/332 [44:08<20:55, 11.84s/it]
#
#
#  68%|██████▊   | 227/332 [44:19<20:19, 11.62s/it]
#
#
#  69%|██████▊   | 228/332 [44:30<20:03, 11.57s/it]
#
#
#  69%|██████▉   | 229/332 [44:43<20:25, 11.89s/it]
#
#
#  69%|██████▉   | 230/332 [44:55<20:30, 12.06s/it]
#
#
#  70%|██████▉   | 231/332 [45:07<20:17, 12.05s/it]
#
#
#  70%|██████▉   | 232/332 [45:19<19:49, 11.90s/it]
#
#
#  70%|███████   | 233/332 [45:31<19:47, 12.00s/it]
#
#
#  70%|███████   | 234/332 [45:43<19:46, 12.11s/it]
#
#
#  71%|███████   | 235/332 [45:55<19:23, 12.00s/it]
#
#
#  71%|███████   | 236/332 [46:06<18:41, 11.68s/it]
#
#
#  71%|███████▏  | 237/332 [46:18<18:39, 11.78s/it]
#
#
#  72%|███████▏  | 238/332 [46:29<18:03, 11.53s/it]
#
#
#  72%|███████▏  | 239/332 [46:40<17:48, 11.49s/it]
#
#
#  72%|███████▏  | 240/332 [46:51<17:24, 11.35s/it]
#
#
#  73%|███████▎  | 241/332 [47:03<17:22, 11.45s/it]
#
#
#  73%|███████▎  | 242/332 [47:15<17:31, 11.69s/it]
#
#
#  73%|███████▎  | 243/332 [47:27<17:14, 11.62s/it]
#
#
#  73%|███████▎  | 244/332 [47:39<17:26, 11.89s/it]
#
#
#  74%|███████▍  | 245/332 [47:51<17:16, 11.91s/it]
#
#
#  74%|███████▍  | 246/332 [48:03<17:08, 11.96s/it]
#
#
#  74%|███████▍  | 247/332 [48:14<16:23, 11.57s/it]
#
#
#  75%|███████▍  | 248/332 [48:25<15:44, 11.25s/it]
#
#
#  75%|███████▌  | 249/332 [48:36<15:45, 11.39s/it]
#
#
#  75%|███████▌  | 250/332 [48:48<15:43, 11.51s/it]
#
#
#  76%|███████▌  | 251/332 [49:00<15:35, 11.54s/it]
#
#
#  76%|███████▌  | 252/332 [49:12<15:40, 11.75s/it]
#
#
#  76%|███████▌  | 253/332 [49:25<16:07, 12.25s/it]
#
#
#  77%|███████▋  | 254/332 [49:38<16:00, 12.31s/it]
#
#
#  77%|███████▋  | 255/332 [49:50<15:43, 12.25s/it]
#
#
#  77%|███████▋  | 256/332 [50:02<15:35, 12.30s/it]
#
#
#  77%|███████▋  | 257/332 [50:14<15:01, 12.02s/it]
#
#
#  78%|███████▊  | 258/332 [50:25<14:30, 11.76s/it]
#
#
#  78%|███████▊  | 259/332 [50:36<14:13, 11.70s/it]
#
#
#  78%|███████▊  | 260/332 [50:48<14:03, 11.72s/it]
#
#
#  79%|███████▊  | 261/332 [50:59<13:24, 11.33s/it]
#
#
#  79%|███████▉  | 262/332 [51:09<13:04, 11.20s/it]
#
#
#  79%|███████▉  | 263/332 [51:21<13:02, 11.34s/it]
#
#
#  80%|███████▉  | 264/332 [51:33<13:07, 11.58s/it]
#
#
#  80%|███████▉  | 265/332 [51:45<12:55, 11.58s/it]
#
#
#  80%|████████  | 266/332 [52:01<14:19, 13.02s/it]
#
#
#  80%|████████  | 267/332 [52:13<13:37, 12.57s/it]
#
#
#  81%|████████  | 268/332 [52:25<13:17, 12.46s/it]
#
#
#  81%|████████  | 269/332 [52:36<12:44, 12.13s/it]
#
#
#  81%|████████▏ | 270/332 [52:48<12:22, 11.97s/it]
#
#
#  82%|████████▏ | 271/332 [52:59<11:48, 11.62s/it]
#
#
#  82%|████████▏ | 272/332 [53:10<11:23, 11.39s/it]
#
#
#  82%|████████▏ | 273/332 [53:20<11:01, 11.22s/it]
#
#
#  83%|████████▎ | 274/332 [53:33<11:14, 11.62s/it]
#
#
#  83%|████████▎ | 275/332 [53:45<11:13, 11.81s/it]
#
#
#  83%|████████▎ | 276/332 [53:57<11:05, 11.88s/it]
#
#
#  83%|████████▎ | 277/332 [54:12<11:46, 12.85s/it]
#
#
#  84%|████████▎ | 278/332 [54:24<11:09, 12.41s/it]
#
#
#  84%|████████▍ | 279/332 [54:36<10:48, 12.23s/it]
#
#
#  84%|████████▍ | 280/332 [54:48<10:39, 12.30s/it]
#
#
#  85%|████████▍ | 281/332 [55:00<10:25, 12.26s/it]
#
#
#  85%|████████▍ | 282/332 [55:13<10:27, 12.55s/it]
#
#
#  85%|████████▌ | 283/332 [55:25<10:02, 12.29s/it]
#
#
#  86%|████████▌ | 284/332 [55:37<09:46, 12.22s/it]
#
#
#  86%|████████▌ | 285/332 [55:49<09:34, 12.22s/it]
#
#
#  86%|████████▌ | 286/332 [56:02<09:20, 12.19s/it]
#
#
#  86%|████████▋ | 287/332 [56:14<09:05, 12.13s/it]
#
#
#  87%|████████▋ | 288/332 [56:24<08:36, 11.75s/it]
#
#
#  87%|████████▋ | 289/332 [56:36<08:28, 11.83s/it]
#
#
#  87%|████████▋ | 290/332 [56:50<08:39, 12.36s/it]
#
#
#  88%|████████▊ | 291/332 [57:03<08:31, 12.47s/it]
#
#
#  88%|████████▊ | 292/332 [57:14<08:06, 12.16s/it]
#
#
#  88%|████████▊ | 293/332 [57:26<07:50, 12.07s/it]
#
#
#  89%|████████▊ | 294/332 [57:37<07:30, 11.86s/it]
#
#
#  89%|████████▉ | 295/332 [57:50<07:31, 12.19s/it]
#
#
#  89%|████████▉ | 296/332 [58:04<07:30, 12.52s/it]
#
#
#  89%|████████▉ | 297/332 [58:15<07:08, 12.23s/it]
#
#
#  90%|████████▉ | 298/332 [58:26<06:40, 11.79s/it]
#
#
#  90%|█████████ | 299/332 [58:38<06:27, 11.75s/it]
#
#
#  90%|█████████ | 300/332 [58:52<06:36, 12.40s/it]
#
#
#  91%|█████████ | 301/332 [59:02<06:06, 11.82s/it]
#
#
#  91%|█████████ | 302/332 [59:16<06:17, 12.58s/it]
#
#
#  91%|█████████▏| 303/332 [59:28<05:55, 12.26s/it]
#
#
#  92%|█████████▏| 304/332 [59:42<05:57, 12.78s/it]
#
#
#  92%|█████████▏| 305/332 [59:54<05:38, 12.54s/it]
#
#
#  92%|█████████▏| 306/332 [1:00:06<05:22, 12.41s/it]
#
#
#  92%|█████████▏| 307/332 [1:00:17<05:02, 12.11s/it]
#
#
#  93%|█████████▎| 308/332 [1:00:29<04:44, 11.87s/it]
#
#
#  93%|█████████▎| 309/332 [1:00:41<04:33, 11.90s/it]
#
#
#  93%|█████████▎| 310/332 [1:00:53<04:27, 12.16s/it]
#
#
#  94%|█████████▎| 311/332 [1:01:05<04:12, 12.04s/it]
#
#
#  94%|█████████▍| 312/332 [1:01:18<04:03, 12.15s/it]
#
#
#  94%|█████████▍| 313/332 [1:01:31<03:58, 12.55s/it]
#
#
#  95%|█████████▍| 314/332 [1:01:42<03:39, 12.21s/it]
#
#
#  95%|█████████▍| 315/332 [1:01:54<03:24, 12.01s/it]
#
#
#  95%|█████████▌| 316/332 [1:02:11<03:35, 13.48s/it]
#
#
#  95%|█████████▌| 317/332 [1:02:23<03:17, 13.18s/it]
#
#
#  96%|█████████▌| 318/332 [1:02:35<02:58, 12.76s/it]
#
#
#  96%|█████████▌| 319/332 [1:02:47<02:42, 12.46s/it]
#
#
#  96%|█████████▋| 320/332 [1:02:58<02:23, 11.95s/it]
#
#
#  97%|█████████▋| 321/332 [1:03:09<02:10, 11.85s/it]
#
#
#  97%|█████████▋| 322/332 [1:03:22<02:00, 12.00s/it]
#
#
#  97%|█████████▋| 323/332 [1:03:34<01:49, 12.14s/it]
#
#
#  98%|█████████▊| 324/332 [1:03:46<01:35, 11.94s/it]
#
#
#  98%|█████████▊| 325/332 [1:03:57<01:21, 11.69s/it]
#
#
#  98%|█████████▊| 326/332 [1:04:08<01:08, 11.48s/it]
#
#
#  98%|█████████▊| 327/332 [1:04:20<00:58, 11.75s/it]
#
#
#  99%|█████████▉| 328/332 [1:04:32<00:47, 11.78s/it]
#
#
#  99%|█████████▉| 329/332 [1:04:44<00:35, 11.96s/it]
#
#
#  99%|█████████▉| 330/332 [1:04:56<00:23, 11.96s/it]
#
#
# 100%|█████████▉| 331/332 [1:05:08<00:11, 11.79s/it]
#
#
# 100%|██████████| 332/332 [1:05:21<00:00, 11.81s/it]
#
#
#
#   0%|          | 0/37 [00:00<?, ?it/s]
#
#
#   3%|▎         | 1/37 [00:11<07:08, 11.91s/it]
#
#
#   5%|▌         | 2/37 [00:23<06:55, 11.88s/it]
#
#
#   8%|▊         | 3/37 [00:36<06:58, 12.30s/it]
#
#
#  11%|█         | 4/37 [00:49<06:43, 12.22s/it]
#
#
#  14%|█▎        | 5/37 [01:00<06:25, 12.04s/it]
#
#
#  16%|█▌        | 6/37 [01:12<06:13, 12.05s/it]
#
#
#  19%|█▉        | 7/37 [01:24<06:00, 12.02s/it]
#
#
#  22%|██▏       | 8/37 [01:35<05:41, 11.77s/it]
#
#
#  24%|██▍       | 9/37 [01:47<05:27, 11.69s/it]
#
#
#  27%|██▋       | 10/37 [01:59<05:22, 11.95s/it]
#
#
#  30%|██▉       | 11/37 [02:12<05:16, 12.19s/it]
#
#
#  32%|███▏      | 12/37 [02:24<05:04, 12.20s/it]
#
#
#  35%|███▌      | 13/37 [02:36<04:46, 11.94s/it]
#
#
#  38%|███▊      | 14/37 [02:47<04:30, 11.78s/it]
#
#
#  41%|████      | 15/37 [02:59<04:22, 11.92s/it]
#
#
#  43%|████▎     | 16/37 [03:12<04:15, 12.16s/it]
#
#
#  46%|████▌     | 17/37 [03:25<04:05, 12.28s/it]
#
#
#  49%|████▊     | 18/37 [03:37<03:51, 12.18s/it]
#
#
#  51%|█████▏    | 19/37 [03:49<03:42, 12.37s/it]
#
#
#  54%|█████▍    | 20/37 [04:02<03:29, 12.30s/it]
#
#
#  57%|█████▋    | 21/37 [04:14<03:15, 12.25s/it]
#
#
#  59%|█████▉    | 22/37 [04:25<03:01, 12.08s/it]
#
#
#  62%|██████▏   | 23/37 [04:38<02:49, 12.11s/it]
#
#
#  65%|██████▍   | 24/37 [04:51<02:41, 12.39s/it]
#
#
#  68%|██████▊   | 25/37 [05:02<02:23, 11.96s/it]
#
#
#  70%|███████   | 26/37 [05:14<02:12, 12.02s/it]
#
#
#  73%|███████▎  | 27/37 [05:26<02:00, 12.09s/it]
#
#
#  76%|███████▌  | 28/37 [05:37<01:46, 11.80s/it]
#
#
#  78%|███████▊  | 29/37 [05:50<01:35, 11.98s/it]
#
#
#  81%|████████  | 30/37 [06:03<01:26, 12.40s/it]
#
#
#  84%|████████▍ | 31/37 [06:16<01:15, 12.56s/it]
#
#
#  86%|████████▋ | 32/37 [06:28<01:01, 12.32s/it]
#
#
#  89%|████████▉ | 33/37 [06:41<00:50, 12.61s/it]
#
#
#  92%|█████████▏| 34/37 [06:59<00:42, 14.33s/it]
#
#
#  95%|█████████▍| 35/37 [07:13<00:28, 14.04s/it]
#
#
#  97%|█████████▋| 36/37 [07:26<00:13, 13.88s/it]
#
#
# 100%|██████████| 37/37 [07:39<00:00, 12.41s/it]

# %% [markdown]
# ## Creating mock dataset for unprocessed data (testing)

# %%
class ModifiedDataset(Dataset):
    def __init__(self, root_dir, postfix=[str(i) for i in range(10)], transformation=None):
        self.files = os.listdir(root_dir)
        self.files = [file for file in self.files if file[-1] in postfix]
        self.root_dir = root_dir
        self.transformation = transformation
    
    def __len__(self):
        return len(self.files) * 155
    
    def __get_file_path(self, idx, postfix):
        return self.root_dir + "/" + self.files[idx] + "/" + self.files[idx] + "_" + postfix + ".nii"
    
    def __getitem__(self, index):
        idx, s = index//155, index % 155
        images = [nib.load(self.__get_file_path(idx, postfix)) for postfix in \
                  ["seg", "t1", "t2", "t1ce"]]
        images = np.array([np.asanyarray(image.dataobj) for image in images])
        images = np.swapaxes(images, 0, 3)
        images = images[s]
        if self.transformation is not None:
            images = self.transformation(images)
        y = np.array(nib.load(self.__get_file_path(idx, "seg")).dataobj)
        y = np.moveaxis(y, 2, 0)
        y = y[s]
        y = np.any(y, (0,1))
        return images, y

# %% [markdown]
# ## Creating DataLoader for the new processed data

# %%
class ProcessedDataset(Dataset):
    def __init__(self, root_dir, datapoints=None):
        if datapoints is None:
            self.files = os.listdir(root_dir)
            self.files = [file for file in self.files if file[-4:] != ".csv"]
        else:
            self.files = [str(i) + "_" + str(j) + ".npy" for i in datapoints for j in range(155)]
        self.root_dir = root_dir
    
    def __len__(self):
        return len(self.files)
    
    def __get_file_path(self, idx):
        return self.root_dir + "/" + self.files[idx] 

    def __getitem__(self, idx):
        if type(idx) == slice:
            data = [self[i] for i in range(len(self))[idx]]
            return [d[0] for d in data], [d[1] for d in data]
        data = np.load(self.__get_file_path(idx), allow_pickle=True)
        return data[0], data[1]

# %%
training_data = ProcessedDataset("./test_data")

# %%
training_data[0][0][:, 0, 0]
# Out:
# array([-0.4137443 , -0.41916734, -0.4353975 ])

# %%
plt.imshow(np.moveaxis(training_data[35][0], 0, 2))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Creating train and test dataloaders

# %%
# !ls
# Out:
# BraTS2020_TrainingData			 model_round2_epoch_18.pt
# BraTS2020_ValidationData		 model_round2_epoch_1.pt
# brats20-dataset-training-validation.zip  model_round2_epoch_2.pt
# mean.npy				 model_round2_epoch_3.pt
# model_epoch_0.pt			 model_round2_epoch_4.pt
# model_round2_epoch_0.pt			 model_round2_epoch_5.pt
# model_round2_epoch_10.pt		 model_round2_epoch_6.pt
# model_round2_epoch_11.pt		 model_round2_epoch_7.pt
# model_round2_epoch_12.pt		 model_round2_epoch_8.pt
# model_round2_epoch_13.pt		 model_round2_epoch_9.pt
# model_round2_epoch_14.pt		 pipeline.pkl
# model_round2_epoch_15.pt		 std.npy
# model_round2_epoch_16.pt		 training_data
# model_round2_epoch_17.pt

# %%
train_dataloader = DataLoader(ProcessedDataset("./training_data", datapoints=train_index),
           batch_size=32, shuffle=True, sampler=None,
           batch_sampler=None, num_workers=16, collate_fn=None,
           pin_memory=False, drop_last=False, timeout=0,
           worker_init_fn=None)
test_dataloader = DataLoader(ProcessedDataset("./test_data", datapoints=test_index),
           batch_size=32, shuffle=True, sampler=None,
           batch_sampler=None, num_workers=16, collate_fn=None,
           pin_memory=False, drop_last=False, timeout=0,
           worker_init_fn=None)
print(len(train_dataloader))
print(len(test_dataloader))
# Out:
# 1609
# 180
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# # Setting up model

# %% [markdown]
# ## Training function

# %%
def train_model(model, criterion, optimizer, scheduler, dataloaders, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            running_examples = 0
            # Iterate over data.
            time0 = time.time()
            for inputs, labels in dataloaders[phase]:
                print("Time loading:", time.time() - time0)
                time0 = time.time()
                print("New batch")
                inputs = inputs.float()
                inputs = inputs.to(device)
                labels = labels.float()
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    labels = labels.reshape_as(outputs)
                    preds = torch.round(torch.sigmoid(outputs))
                    loss = criterion(outputs, labels)
                    print(loss)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels)
                running_examples += len(inputs)
                
                print("Time executing:", time.time() - time0)
                time0 = time.time()
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / running_examples
            epoch_acc = running_corrects.double() / running_examples

            if phase == "train":
                with open("loss.txt", "a") as f:
                    f.write('Epoch {}: Loss: {:.4f} Acc: {:.4f}\n'.format(epoch,
                        epoch_loss, epoch_acc))

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
        torch.save(model, "model_round11_epoch_" + str(epoch) + ".pt")
        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# ## Creating model

# %%
model_conv = models.vgg16(pretrained=True)
for param in model_conv.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
model_conv.classifier[6] = nn.Linear(4096, 1)

model_conv = model_conv.to(device)

criterion = nn.BCEWithLogitsLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_conv.classifier[6].parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# HBox(children=(FloatProgress(value=0.0, max=553433881.0), HTML(value='')))

# %%
#del model_conv
torch.cuda.empty_cache()
model_conv = models.vgg16(pretrained=True)

# Parameters of newly constructed modules have requires_grad=True by default
model_conv.classifier[6] = nn.Linear(4096, 1)

model_conv = model_conv.to(device)

# %%
criterion = nn.BCEWithLogitsLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_conv.parameters(), lr=0.00001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
#del model_conv
torch.cuda.empty_cache()
model_conv = torch.load("model_round10_epoch_9.pt").to(device)

# %%
model_conv = model_conv.to(device)

# %%
model_conv
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# # Training model

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
import os
import sys
import psutil


def kill_child_proc(ppid):
    for process in psutil.process_iter():
        _ppid = process.ppid()
        if _ppid == ppid:
            _pid = process.pid
            if sys.platform == 'win32':
                process.terminate()
            else:
                os.system('kill -9 {0}'.format(_pid))

# %%
kill_child_proc(58)

# %%
import multiprocessing
multiprocessing.active_children()
# Out:
# [<Process(Process-7, started daemon)>,
#  <Process(Process-9, started daemon)>,
#  <Process(Process-11, started daemon)>,
#  <Process(Process-13, started daemon)>,
#  <Process(Process-16, started daemon)>,
#  <Process(Process-1, started daemon)>,
#  <Process(Process-5, started daemon)>,
#  <Process(Process-6, started daemon)>,
#  <Process(Process-4, started daemon)>,
#  <Process(Process-10, started daemon)>,
#  <Process(Process-12, started daemon)>,
#  <Process(Process-15, started daemon)>,
#  <Process(Process-2, started daemon)>,
#  <Process(Process-14, started daemon)>,
#  <Process(Process-8, started daemon)>,
#  <Process(Process-3, started daemon)>]

# %%
# !ps -efj
# Out:
# UID          PID    PPID    PGID     SID  C STIME TTY          TIME CMD
# root           1       0       1       1  0 16:20 ?        00:00:01 /tools/node/
# root          14       0      14      14  0 16:20 ?        00:00:00 tail -n +0 -
# root          46       1       1       1  0 16:20 ?        00:00:01 /usr/bin/pyt
# root          47       1       1       1  0 16:20 ?        00:00:00 /usr/local/b
# root          58      46      58      58  2 16:21 ?        00:00:09 /usr/bin/pyt
# root          93       1      74      74  0 16:21 ?        00:00:00 /bin/bash --
# root          94      93      74      74  0 16:21 ?        00:00:00 /opt/google/
# root          95      93      74      74  0 16:21 ?        00:00:00 grep --color
# root         176      94      74      74  3 16:22 ?        00:00:10 /opt/google/
# root         230       1      74      74  0 16:22 ?        00:00:00 bash -c tail
# root         231     230      74      74  0 16:22 ?        00:00:00 tail -n +0 -
# root         232     230      74      74  0 16:22 ?        00:00:00 python3 /opt
# root         281      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         283      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         285      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         287      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         289      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         291      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         293      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         295      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         297      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         299      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         301      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         303      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         305      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         307      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         309      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         311      58      58      58  0 16:25 ?        00:00:00 /usr/bin/pyt
# root         400      58      58      58  0 16:27 ?        00:00:00 ps -efj

# %%
 torch.cuda.empty_cache()

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,
                         exp_lr_scheduler, {"train": train_dataloader, "val": test_dataloader}, num_epochs=24)
# Out:
# Epoch 0/23
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Streaming output truncated to the last 5000 lines.
# Time executing: 0.43793821334838867
# Time loading: 0.0007073879241943359
# New batch
# tensor(0.2094, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4427011013031006
# Time loading: 8.107217073440552
# New batch
# tensor(0.2902, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5396840572357178
# Time loading: 0.0008904933929443359
# New batch
# tensor(0.4293, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4381251335144043
# Time loading: 0.0015490055084228516
# New batch
# tensor(0.2115, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43828916549682617
# Time loading: 0.0009806156158447266
# New batch
# tensor(0.3957, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.49657344818115234
# Time loading: 0.0020246505737304688
# New batch
# tensor(0.4336, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4401862621307373
# Time loading: 0.0008981227874755859
# New batch
# tensor(0.2208, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4824252128601074
# Time loading: 0.0007390975952148438
# New batch
# tensor(0.4004, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43811535835266113
# Time loading: 0.0003268718719482422
# New batch
# tensor(0.3411, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4455573558807373
# Time loading: 0.0007445812225341797
# New batch
# tensor(0.2902, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.437147855758667
# Time loading: 0.00032448768615722656
# New batch
# tensor(0.3000, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.453127384185791
# Time loading: 0.0006232261657714844
# New batch
# tensor(0.3048, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4369955062866211
# Time loading: 0.0007390975952148438
# New batch
# tensor(0.2667, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44799375534057617
# Time loading: 0.002243518829345703
# New batch
# tensor(0.4253, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.49607300758361816
# Time loading: 0.011213302612304688
# New batch
# tensor(0.2655, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4514620304107666
# Time loading: 0.0009551048278808594
# New batch
# tensor(0.2711, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.438387393951416
# Time loading: 0.0007205009460449219
# New batch
# tensor(0.3261, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43806934356689453
# Time loading: 11.679935455322266
# New batch
# tensor(0.2968, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5060782432556152
# Time loading: 0.0005738735198974609
# New batch
# tensor(0.3031, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4388391971588135
# Time loading: 0.0001533031463623047
# New batch
# tensor(0.3780, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4400453567504883
# Time loading: 0.0006351470947265625
# New batch
# tensor(0.3906, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4387552738189697
# Time loading: 0.0005528926849365234
# New batch
# tensor(0.4138, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45724916458129883
# Time loading: 0.001344919204711914
# New batch
# tensor(0.4620, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4555542469024658
# Time loading: 0.0021452903747558594
# New batch
# tensor(0.2637, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44979310035705566
# Time loading: 0.0004582405090332031
# New batch
# tensor(0.3187, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4389379024505615
# Time loading: 0.0008392333984375
# New batch
# tensor(0.3422, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5018284320831299
# Time loading: 0.0006899833679199219
# New batch
# tensor(0.3401, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43750452995300293
# Time loading: 0.00019860267639160156
# New batch
# tensor(0.3843, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44257521629333496
# Time loading: 0.0008282661437988281
# New batch
# tensor(0.2884, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4391777515411377
# Time loading: 0.0007886886596679688
# New batch
# tensor(0.2326, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43732166290283203
# Time loading: 0.0022394657135009766
# New batch
# tensor(0.2950, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44033288955688477
# Time loading: 0.001149892807006836
# New batch
# tensor(0.3683, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4418606758117676
# Time loading: 0.0006999969482421875
# New batch
# tensor(0.2887, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45224523544311523
# Time loading: 8.48852252960205
# New batch
# tensor(0.2377, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5015401840209961
# Time loading: 0.00017905235290527344
# New batch
# tensor(0.3846, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.49596667289733887
# Time loading: 0.0004296302795410156
# New batch
# tensor(0.3218, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4415006637573242
# Time loading: 0.0008544921875
# New batch
# tensor(0.3268, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43473124504089355
# Time loading: 0.0010018348693847656
# New batch
# tensor(0.3234, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4395606517791748
# Time loading: 0.0001647472381591797
# New batch
# tensor(0.5674, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43897485733032227
# Time loading: 0.0006651878356933594
# New batch
# tensor(0.3310, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4855787754058838
# Time loading: 0.0012280941009521484
# New batch
# tensor(0.3933, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4716453552246094
# Time loading: 0.002184152603149414
# New batch
# tensor(0.1217, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4720628261566162
# Time loading: 0.0005168914794921875
# New batch
# tensor(0.4577, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4502570629119873
# Time loading: 0.0001742839813232422
# New batch
# tensor(0.2866, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44426703453063965
# Time loading: 0.00017786026000976562
# New batch
# tensor(0.3123, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44123148918151855
# Time loading: 0.0008378028869628906
# New batch
# tensor(0.4032, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4385080337524414
# Time loading: 0.0008211135864257812
# New batch
# tensor(0.1922, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4403088092803955
# Time loading: 0.0003554821014404297
# New batch
# tensor(0.2654, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45853614807128906
# Time loading: 0.0007231235504150391
# New batch
# tensor(0.3537, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4383089542388916
# Time loading: 10.980964183807373
# New batch
# tensor(0.4154, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5272302627563477
# Time loading: 0.0028302669525146484
# New batch
# tensor(0.2824, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4463479518890381
# Time loading: 0.0002849102020263672
# New batch
# tensor(0.3973, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4479079246520996
# Time loading: 0.0002722740173339844
# New batch
# tensor(0.2965, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.49931836128234863
# Time loading: 0.0016231536865234375
# New batch
# tensor(0.3986, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45429396629333496
# Time loading: 0.00020575523376464844
# New batch
# tensor(0.2116, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47210168838500977
# Time loading: 0.00033926963806152344
# New batch
# tensor(0.3405, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4632725715637207
# Time loading: 0.00044655799865722656
# New batch
# tensor(0.1847, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48259973526000977
# Time loading: 0.0008678436279296875
# New batch
# tensor(0.5378, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44334912300109863
# Time loading: 0.0006425380706787109
# New batch
# tensor(0.3997, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45102834701538086
# Time loading: 0.001027822494506836
# New batch
# tensor(0.2027, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46703338623046875
# Time loading: 0.0003628730773925781
# New batch
# tensor(0.2394, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4527585506439209
# Time loading: 0.00029730796813964844
# New batch
# tensor(0.2523, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4499824047088623
# Time loading: 0.0007948875427246094
# New batch
# tensor(0.2533, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43975186347961426
# Time loading: 0.0007336139678955078
# New batch
# tensor(0.2794, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43912243843078613
# Time loading: 0.0009288787841796875
# New batch
# tensor(0.3018, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.441070556640625
# Time loading: 9.074143886566162
# New batch
# tensor(0.5682, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5061147212982178
# Time loading: 0.0002887248992919922
# New batch
# tensor(0.3079, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4963076114654541
# Time loading: 0.0013499259948730469
# New batch
# tensor(0.3689, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4701876640319824
# Time loading: 0.00035190582275390625
# New batch
# tensor(0.2126, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4399759769439697
# Time loading: 0.0003476142883300781
# New batch
# tensor(0.3604, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4601271152496338
# Time loading: 0.0007452964782714844
# New batch
# tensor(0.2362, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4413459300994873
# Time loading: 0.0004303455352783203
# New batch
# tensor(0.3060, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47315073013305664
# Time loading: 0.0009815692901611328
# New batch
# tensor(0.2936, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44627833366394043
# Time loading: 0.0002772808074951172
# New batch
# tensor(0.3078, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44159626960754395
# Time loading: 0.0005342960357666016
# New batch
# tensor(0.1935, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4526796340942383
# Time loading: 0.0029811859130859375
# New batch
# tensor(0.3495, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.453815221786499
# Time loading: 0.0007417201995849609
# New batch
# tensor(0.2150, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4405066967010498
# Time loading: 0.0003666877746582031
# New batch
# tensor(0.3379, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4399418830871582
# Time loading: 0.0009469985961914062
# New batch
# tensor(0.2666, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4578890800476074
# Time loading: 0.0004112720489501953
# New batch
# tensor(0.3534, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44176626205444336
# Time loading: 0.0009646415710449219
# New batch
# tensor(0.2014, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4475688934326172
# Time loading: 10.345845699310303
# New batch
# tensor(0.5557, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5064890384674072
# Time loading: 0.003954172134399414
# New batch
# tensor(0.3040, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5486397743225098
# Time loading: 0.0007457733154296875
# New batch
# tensor(0.2058, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43962812423706055
# Time loading: 0.002218961715698242
# New batch
# tensor(0.2803, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5351622104644775
# Time loading: 0.002000093460083008
# New batch
# tensor(0.2933, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4496614933013916
# Time loading: 0.0005950927734375
# New batch
# tensor(0.1854, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45342350006103516
# Time loading: 0.0007383823394775391
# New batch
# tensor(0.4177, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4382305145263672
# Time loading: 0.0017940998077392578
# New batch
# tensor(0.2122, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5002679824829102
# Time loading: 0.00023889541625976562
# New batch
# tensor(0.2866, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45812487602233887
# Time loading: 0.0003066062927246094
# New batch
# tensor(0.2486, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44399118423461914
# Time loading: 0.0012085437774658203
# New batch
# tensor(0.4626, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4427988529205322
# Time loading: 0.0009591579437255859
# New batch
# tensor(0.2853, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4586610794067383
# Time loading: 0.0002899169921875
# New batch
# tensor(0.3198, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4527435302734375
# Time loading: 0.0010008811950683594
# New batch
# tensor(0.1840, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44920969009399414
# Time loading: 0.000354766845703125
# New batch
# tensor(0.3376, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48082780838012695
# Time loading: 0.0002875328063964844
# New batch
# tensor(0.3487, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44342494010925293
# Time loading: 6.702210187911987
# New batch
# tensor(0.2884, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5356862545013428
# Time loading: 0.0024428367614746094
# New batch
# tensor(0.2671, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45850205421447754
# Time loading: 0.0005931854248046875
# New batch
# tensor(0.3717, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4516274929046631
# Time loading: 0.0016827583312988281
# New batch
# tensor(0.3305, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46881604194641113
# Time loading: 0.012908935546875
# New batch
# tensor(0.5222, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45630955696105957
# Time loading: 0.000720977783203125
# New batch
# tensor(0.3887, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44062256813049316
# Time loading: 0.0013620853424072266
# New batch
# tensor(0.3289, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45055365562438965
# Time loading: 0.00042057037353515625
# New batch
# tensor(0.3047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4384474754333496
# Time loading: 0.0009207725524902344
# New batch
# tensor(0.4241, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43966245651245117
# Time loading: 0.0008857250213623047
# New batch
# tensor(0.3834, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4534173011779785
# Time loading: 0.0028390884399414062
# New batch
# tensor(0.2756, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4552645683288574
# Time loading: 0.001054525375366211
# New batch
# tensor(0.3204, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43823814392089844
# Time loading: 0.00069427490234375
# New batch
# tensor(0.4368, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44371891021728516
# Time loading: 0.001214742660522461
# New batch
# tensor(0.2593, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4382193088531494
# Time loading: 0.001001119613647461
# New batch
# tensor(0.2339, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44852685928344727
# Time loading: 0.02134561538696289
# New batch
# tensor(0.2927, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4427499771118164
# Time loading: 9.952032566070557
# New batch
# tensor(0.3567, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4950580596923828
# Time loading: 0.00020956993103027344
# New batch
# tensor(0.2646, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4519052505493164
# Time loading: 0.0003161430358886719
# New batch
# tensor(0.2474, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44126009941101074
# Time loading: 0.0010218620300292969
# New batch
# tensor(0.4044, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48561763763427734
# Time loading: 0.00027632713317871094
# New batch
# tensor(0.2867, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.451094388961792
# Time loading: 0.0055234432220458984
# New batch
# tensor(0.2587, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47490429878234863
# Time loading: 0.0009000301361083984
# New batch
# tensor(0.2300, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4563770294189453
# Time loading: 0.0007646083831787109
# New batch
# tensor(0.2805, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45015978813171387
# Time loading: 0.002872467041015625
# New batch
# tensor(0.2108, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44759392738342285
# Time loading: 0.0002124309539794922
# New batch
# tensor(0.5822, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44182825088500977
# Time loading: 0.0007774829864501953
# New batch
# tensor(0.3523, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43997859954833984
# Time loading: 0.0008990764617919922
# New batch
# tensor(0.3630, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4432685375213623
# Time loading: 0.00043845176696777344
# New batch
# tensor(0.2467, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.453155517578125
# Time loading: 0.0007898807525634766
# New batch
# tensor(0.5396, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4448559284210205
# Time loading: 0.0009663105010986328
# New batch
# tensor(0.2467, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4427006244659424
# Time loading: 0.0007634162902832031
# New batch
# tensor(0.4052, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46647000312805176
# Time loading: 7.66328763961792
# New batch
# tensor(0.4148, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5285310745239258
# Time loading: 0.0008928775787353516
# New batch
# tensor(0.3353, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4548027515411377
# Time loading: 0.0009047985076904297
# New batch
# tensor(0.4402, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4411022663116455
# Time loading: 0.005901336669921875
# New batch
# tensor(0.3324, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48887157440185547
# Time loading: 0.00027251243591308594
# New batch
# tensor(0.2991, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4389681816101074
# Time loading: 0.0009980201721191406
# New batch
# tensor(0.3210, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4404292106628418
# Time loading: 0.00025963783264160156
# New batch
# tensor(0.1630, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4736475944519043
# Time loading: 0.00020241737365722656
# New batch
# tensor(0.2716, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43916773796081543
# Time loading: 0.0007290840148925781
# New batch
# tensor(0.2122, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4459681510925293
# Time loading: 0.0014903545379638672
# New batch
# tensor(0.4053, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44214653968811035
# Time loading: 0.0008578300476074219
# New batch
# tensor(0.1878, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44077539443969727
# Time loading: 0.00048041343688964844
# New batch
# tensor(0.5426, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4591660499572754
# Time loading: 0.0003383159637451172
# New batch
# tensor(0.2387, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44341254234313965
# Time loading: 0.0010120868682861328
# New batch
# tensor(0.2420, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4391441345214844
# Time loading: 0.0008275508880615234
# New batch
# tensor(0.2666, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4423990249633789
# Time loading: 0.00018024444580078125
# New batch
# tensor(0.4666, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4384140968322754
# Time loading: 11.735065221786499
# New batch
# tensor(0.3674, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5163476467132568
# Time loading: 0.0009124279022216797
# New batch
# tensor(0.2970, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4883906841278076
# Time loading: 0.00029921531677246094
# New batch
# tensor(0.3006, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48604464530944824
# Time loading: 0.0011484622955322266
# New batch
# tensor(0.2344, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44983482360839844
# Time loading: 0.0030651092529296875
# New batch
# tensor(0.2026, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4386920928955078
# Time loading: 0.0007758140563964844
# New batch
# tensor(0.2985, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4377143383026123
# Time loading: 0.0007646083831787109
# New batch
# tensor(0.2610, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44469380378723145
# Time loading: 0.0009407997131347656
# New batch
# tensor(0.3489, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5069317817687988
# Time loading: 0.0003414154052734375
# New batch
# tensor(0.2019, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44558119773864746
# Time loading: 0.0008957386016845703
# New batch
# tensor(0.3214, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48627543449401855
# Time loading: 0.005057096481323242
# New batch
# tensor(0.3448, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4561922550201416
# Time loading: 0.0009641647338867188
# New batch
# tensor(0.3958, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44565415382385254
# Time loading: 0.0007882118225097656
# New batch
# tensor(0.2599, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44879961013793945
# Time loading: 0.000885009765625
# New batch
# tensor(0.3270, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4748377799987793
# Time loading: 0.0006165504455566406
# New batch
# tensor(0.4442, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44362735748291016
# Time loading: 0.00022721290588378906
# New batch
# tensor(0.2943, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.501838207244873
# Time loading: 8.184061765670776
# New batch
# tensor(0.1756, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5460176467895508
# Time loading: 0.0024569034576416016
# New batch
# tensor(0.2720, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4515345096588135
# Time loading: 0.0007848739624023438
# New batch
# tensor(0.3817, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43912768363952637
# Time loading: 0.0002918243408203125
# New batch
# tensor(0.4409, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4471120834350586
# Time loading: 0.009336233139038086
# New batch
# tensor(0.3861, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.446671724319458
# Time loading: 0.0003466606140136719
# New batch
# tensor(0.2321, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44684290885925293
# Time loading: 0.0011234283447265625
# New batch
# tensor(0.2932, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4398477077484131
# Time loading: 0.00035262107849121094
# New batch
# tensor(0.3364, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46047544479370117
# Time loading: 0.0014696121215820312
# New batch
# tensor(0.3763, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4489407539367676
# Time loading: 0.0002079010009765625
# New batch
# tensor(0.2824, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4386911392211914
# Time loading: 0.0007672309875488281
# New batch
# tensor(0.3960, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4399380683898926
# Time loading: 0.0010600090026855469
# New batch
# tensor(0.2746, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45659708976745605
# Time loading: 0.0006284713745117188
# New batch
# tensor(0.3310, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4430513381958008
# Time loading: 0.0010471343994140625
# New batch
# tensor(0.3323, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5011770725250244
# Time loading: 0.00027060508728027344
# New batch
# tensor(0.3119, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4621586799621582
# Time loading: 0.0010187625885009766
# New batch
# tensor(0.4882, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4421811103820801
# Time loading: 9.62950325012207
# New batch
# tensor(0.4180, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5245058536529541
# Time loading: 0.001094818115234375
# New batch
# tensor(0.2396, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4474906921386719
# Time loading: 0.0003077983856201172
# New batch
# tensor(0.3566, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4440600872039795
# Time loading: 0.0003464221954345703
# New batch
# tensor(0.4060, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4503476619720459
# Time loading: 0.002147674560546875
# New batch
# tensor(0.3840, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4564065933227539
# Time loading: 0.0010516643524169922
# New batch
# tensor(0.4696, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47873950004577637
# Time loading: 0.00019788742065429688
# New batch
# tensor(0.2847, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4543476104736328
# Time loading: 0.0007352828979492188
# New batch
# tensor(0.3913, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4443783760070801
# Time loading: 0.0005145072937011719
# New batch
# tensor(0.4145, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4685380458831787
# Time loading: 0.0003466606140136719
# New batch
# tensor(0.3111, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46013784408569336
# Time loading: 0.0007441043853759766
# New batch
# tensor(0.4291, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44258975982666016
# Time loading: 0.00031256675720214844
# New batch
# tensor(0.2701, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44498133659362793
# Time loading: 0.0004417896270751953
# New batch
# tensor(0.3383, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4400177001953125
# Time loading: 0.0002841949462890625
# New batch
# tensor(0.2067, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44103312492370605
# Time loading: 0.0003314018249511719
# New batch
# tensor(0.4641, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45194196701049805
# Time loading: 0.0009405612945556641
# New batch
# tensor(0.3264, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43961000442504883
# Time loading: 11.06704592704773
# New batch
# tensor(0.4465, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5366480350494385
# Time loading: 0.0003268718719482422
# New batch
# tensor(0.3667, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44997358322143555
# Time loading: 0.00031495094299316406
# New batch
# tensor(0.1989, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43739914894104004
# Time loading: 0.0002048015594482422
# New batch
# tensor(0.4503, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4403855800628662
# Time loading: 0.0007748603820800781
# New batch
# tensor(0.1800, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4385225772857666
# Time loading: 0.00021266937255859375
# New batch
# tensor(0.3202, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4615745544433594
# Time loading: 0.0003223419189453125
# New batch
# tensor(0.2411, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4446988105773926
# Time loading: 0.0004684925079345703
# New batch
# tensor(0.2642, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4588937759399414
# Time loading: 0.0007803440093994141
# New batch
# tensor(0.2293, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4639718532562256
# Time loading: 0.0030105113983154297
# New batch
# tensor(0.3946, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4885852336883545
# Time loading: 0.00032973289489746094
# New batch
# tensor(0.3828, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46273136138916016
# Time loading: 0.0007677078247070312
# New batch
# tensor(0.2638, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43873095512390137
# Time loading: 0.0013515949249267578
# New batch
# tensor(0.3386, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46399617195129395
# Time loading: 0.0009636878967285156
# New batch
# tensor(0.2732, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4428236484527588
# Time loading: 0.0007879734039306641
# New batch
# tensor(0.3933, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4385530948638916
# Time loading: 0.00037288665771484375
# New batch
# tensor(0.3976, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4447760581970215
# Time loading: 6.7201995849609375
# New batch
# tensor(0.2477, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5536775588989258
# Time loading: 0.0017690658569335938
# New batch
# tensor(0.2447, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.49068593978881836
# Time loading: 0.004825592041015625
# New batch
# tensor(0.2144, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46158671379089355
# Time loading: 0.00023555755615234375
# New batch
# tensor(0.3767, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4557936191558838
# Time loading: 0.0008928775787353516
# New batch
# tensor(0.2339, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4448223114013672
# Time loading: 0.0003452301025390625
# New batch
# tensor(0.3366, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44553136825561523
# Time loading: 0.0035572052001953125
# New batch
# tensor(0.1693, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4410240650177002
# Time loading: 0.0005371570587158203
# New batch
# tensor(0.3236, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43753647804260254
# Time loading: 0.0007798671722412109
# New batch
# tensor(0.5024, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4515047073364258
# Time loading: 0.0009379386901855469
# New batch
# tensor(0.2342, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4392967224121094
# Time loading: 0.0006165504455566406
# New batch
# tensor(0.4815, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4428708553314209
# Time loading: 0.000997304916381836
# New batch
# tensor(0.2365, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44452881813049316
# Time loading: 0.0008640289306640625
# New batch
# tensor(0.3159, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4453256130218506
# Time loading: 0.0007369518280029297
# New batch
# tensor(0.3154, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4407675266265869
# Time loading: 0.0007817745208740234
# New batch
# tensor(0.3245, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44027185440063477
# Time loading: 0.0006959438323974609
# New batch
# tensor(0.2656, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44295430183410645
# Time loading: 9.397038698196411
# New batch
# tensor(0.3157, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5233862400054932
# Time loading: 0.0007510185241699219
# New batch
# tensor(0.4393, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4388411045074463
# Time loading: 0.0003135204315185547
# New batch
# tensor(0.3106, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4444580078125
# Time loading: 0.00030994415283203125
# New batch
# tensor(0.3605, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4425160884857178
# Time loading: 0.0009720325469970703
# New batch
# tensor(0.2352, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43826913833618164
# Time loading: 0.0018546581268310547
# New batch
# tensor(0.2471, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44689083099365234
# Time loading: 0.0005578994750976562
# New batch
# tensor(0.3270, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45862483978271484
# Time loading: 0.0009512901306152344
# New batch
# tensor(0.3688, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.438030481338501
# Time loading: 0.00030303001403808594
# New batch
# tensor(0.3593, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43987011909484863
# Time loading: 0.00148773193359375
# New batch
# tensor(0.4752, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43599939346313477
# Time loading: 0.00018668174743652344
# New batch
# tensor(0.4513, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44391846656799316
# Time loading: 0.003410816192626953
# New batch
# tensor(0.3216, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4632833003997803
# Time loading: 0.00036215782165527344
# New batch
# tensor(0.5703, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4443173408508301
# Time loading: 0.0006034374237060547
# New batch
# tensor(0.3009, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44594764709472656
# Time loading: 0.0007772445678710938
# New batch
# tensor(0.1775, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4447605609893799
# Time loading: 0.0007984638214111328
# New batch
# tensor(0.3422, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4407203197479248
# Time loading: 9.29680585861206
# New batch
# tensor(0.2142, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5868475437164307
# Time loading: 0.0007500648498535156
# New batch
# tensor(0.4743, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43668198585510254
# Time loading: 0.001397848129272461
# New batch
# tensor(0.6934, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45346879959106445
# Time loading: 0.0010294914245605469
# New batch
# tensor(0.1336, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44017624855041504
# Time loading: 0.0034589767456054688
# New batch
# tensor(0.4485, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4382302761077881
# Time loading: 0.0008378028869628906
# New batch
# tensor(0.2518, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43620896339416504
# Time loading: 0.0005364418029785156
# New batch
# tensor(0.2348, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4507920742034912
# Time loading: 0.00035119056701660156
# New batch
# tensor(0.4362, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4586975574493408
# Time loading: 0.0007607936859130859
# New batch
# tensor(0.2742, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44051456451416016
# Time loading: 0.0009658336639404297
# New batch
# tensor(0.3776, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4396543502807617
# Time loading: 0.0005743503570556641
# New batch
# tensor(0.2413, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43877291679382324
# Time loading: 0.00024962425231933594
# New batch
# tensor(0.4584, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4405398368835449
# Time loading: 0.00017714500427246094
# New batch
# tensor(0.3721, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4361262321472168
# Time loading: 0.0006506443023681641
# New batch
# tensor(0.4324, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43834996223449707
# Time loading: 0.00014066696166992188
# New batch
# tensor(0.3149, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4404752254486084
# Time loading: 0.00014162063598632812
# New batch
# tensor(0.3251, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43830370903015137
# Time loading: 9.38361930847168
# New batch
# tensor(0.3705, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5350039005279541
# Time loading: 0.00032711029052734375
# New batch
# tensor(0.1678, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44879603385925293
# Time loading: 0.0009007453918457031
# New batch
# tensor(0.4786, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45090556144714355
# Time loading: 0.00034308433532714844
# New batch
# tensor(0.2438, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4999654293060303
# Time loading: 0.002117156982421875
# New batch
# tensor(0.2567, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43822407722473145
# Time loading: 0.0006592273712158203
# New batch
# tensor(0.5145, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45093464851379395
# Time loading: 0.0007522106170654297
# New batch
# tensor(0.2960, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4400334358215332
# Time loading: 0.0008161067962646484
# New batch
# tensor(0.3980, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4454801082611084
# Time loading: 0.00016570091247558594
# New batch
# tensor(0.4409, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43935251235961914
# Time loading: 0.000263214111328125
# New batch
# tensor(0.2355, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44032931327819824
# Time loading: 0.0004963874816894531
# New batch
# tensor(0.4499, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.437821626663208
# Time loading: 0.0008635520935058594
# New batch
# tensor(0.3014, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4384579658508301
# Time loading: 0.00017762184143066406
# New batch
# tensor(0.2619, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43891286849975586
# Time loading: 0.0009636878967285156
# New batch
# tensor(0.2519, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44653940200805664
# Time loading: 0.00023508071899414062
# New batch
# tensor(0.4882, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4476776123046875
# Time loading: 0.00020837783813476562
# New batch
# tensor(0.2228, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45809316635131836
# Time loading: 10.149599552154541
# New batch
# tensor(0.1907, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5014452934265137
# Time loading: 0.0007393360137939453
# New batch
# tensor(0.2297, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4390838146209717
# Time loading: 0.00019741058349609375
# New batch
# tensor(0.3531, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.447113037109375
# Time loading: 0.0006852149963378906
# New batch
# tensor(0.2687, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4632260799407959
# Time loading: 0.0006575584411621094
# New batch
# tensor(0.2376, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4409961700439453
# Time loading: 0.0005207061767578125
# New batch
# tensor(0.3690, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47017526626586914
# Time loading: 0.00261688232421875
# New batch
# tensor(0.3087, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4835946559906006
# Time loading: 0.0009367465972900391
# New batch
# tensor(0.4147, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.43640780448913574
# Time loading: 0.00027251243591308594
# New batch
# tensor(0.2911, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4368007183074951
# Time loading: 0.0002551078796386719
# New batch
# tensor(0.2169, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4387941360473633
# Time loading: 0.0006449222564697266
# New batch
# tensor(0.3036, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4378037452697754
# Time loading: 0.00040602684020996094
# New batch
# tensor(0.2365, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44225478172302246
# Time loading: 0.0009412765502929688
# New batch
# tensor(0.2346, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44142580032348633
# Time loading: 0.0005900859832763672
# New batch
# tensor(0.3382, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44599413871765137
# Time loading: 0.0002689361572265625
# New batch
# tensor(0.3480, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44750094413757324
# Time loading: 0.0009989738464355469
# New batch
# tensor(0.3745, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.510474681854248
# Time loading: 8.703481435775757
# New batch
# tensor(0.3074, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5093245506286621
# Time loading: 0.0007326602935791016
# New batch
# tensor(0.1971, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4427306652069092
# Time loading: 0.0018932819366455078
# New batch
# tensor(0.1292, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5121002197265625
# Time loading: 0.0009579658508300781
# New batch
# tensor(0.3521, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.44153881072998047
# Time loading: 0.0050411224365234375
# New batch
# tensor(0.1833, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48784327507019043
# Time loading: 0.0010886192321777344
# New batch
# ...
# Time executing: 0.5157036781311035
# Time loading: 0.00021886825561523438
# New batch
# tensor(0.2266, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4586954116821289
# Time loading: 0.0008678436279296875
# New batch
# tensor(0.4707, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4586303234100342
# Time loading: 2.9228320121765137
# New batch
# tensor(0.4262, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5131125450134277
# Time loading: 0.0007586479187011719
# New batch
# tensor(0.2150, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4537692070007324
# Time loading: 0.0010256767272949219
# New batch
# tensor(0.3905, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46674466133117676
# Time loading: 0.00019478797912597656
# New batch
# tensor(0.2783, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47338390350341797
# Time loading: 0.0051310062408447266
# New batch
# tensor(0.2718, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46678757667541504
# Time loading: 3.859156608581543
# New batch
# tensor(0.4317, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5061006546020508
# Time loading: 0.00028252601623535156
# New batch
# tensor(0.2742, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46729421615600586
# Time loading: 0.0008974075317382812
# New batch
# tensor(0.3257, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46773695945739746
# Time loading: 0.000461578369140625
# New batch
# tensor(0.3662, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45874547958374023
# Time loading: 0.0018341541290283203
# New batch
# tensor(0.4422, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4610910415649414
# Time loading: 0.0010259151458740234
# New batch
# tensor(0.2072, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45750880241394043
# Time loading: 0.00037860870361328125
# New batch
# tensor(0.2969, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5638003349304199
# Time loading: 0.0005512237548828125
# New batch
# tensor(0.3097, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4589991569519043
# Time loading: 0.0004458427429199219
# New batch
# tensor(0.4466, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5286190509796143
# Time loading: 0.00017905235290527344
# New batch
# tensor(0.2497, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48657774925231934
# Time loading: 0.0006301403045654297
# New batch
# tensor(0.2718, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4541893005371094
# Time loading: 5.761637449264526
# New batch
# tensor(0.3390, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5094983577728271
# Time loading: 0.00022649765014648438
# New batch
# tensor(0.2732, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46629929542541504
# Time loading: 0.0012412071228027344
# New batch
# tensor(0.2649, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45782470703125
# Time loading: 0.00044465065002441406
# New batch
# tensor(0.3253, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4551098346710205
# Time loading: 0.005585432052612305
# New batch
# tensor(0.2670, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4531545639038086
# Time loading: 5.029510974884033
# New batch
# tensor(0.2898, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.530137300491333
# Time loading: 0.0032906532287597656
# New batch
# tensor(0.3221, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4579598903656006
# Time loading: 0.0018062591552734375
# New batch
# tensor(0.3306, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45380568504333496
# Time loading: 0.0008943080902099609
# New batch
# tensor(0.3020, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4551236629486084
# Time loading: 0.0009329319000244141
# New batch
# tensor(0.2212, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45398545265197754
# Time loading: 0.0003972053527832031
# New batch
# tensor(0.3564, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45682191848754883
# Time loading: 0.00041103363037109375
# New batch
# tensor(0.2510, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4549586772918701
# Time loading: 0.0007026195526123047
# New batch
# tensor(0.2803, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45967769622802734
# Time loading: 0.0009915828704833984
# New batch
# tensor(0.3874, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4557912349700928
# Time loading: 0.0007321834564208984
# New batch
# tensor(0.2955, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4735751152038574
# Time loading: 0.0014393329620361328
# New batch
# tensor(0.3386, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46826767921447754
# Time loading: 4.197958469390869
# New batch
# tensor(0.3143, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5359096527099609
# Time loading: 0.0002675056457519531
# New batch
# tensor(0.2772, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48345255851745605
# Time loading: 0.00021839141845703125
# New batch
# tensor(0.3742, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4715268611907959
# Time loading: 0.0010733604431152344
# New batch
# tensor(0.2146, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47144055366516113
# Time loading: 0.0027315616607666016
# New batch
# tensor(0.4485, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45230889320373535
# Time loading: 5.349452257156372
# New batch
# tensor(0.4307, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5589554309844971
# Time loading: 0.004277944564819336
# New batch
# tensor(0.2808, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4976809024810791
# Time loading: 0.001096963882446289
# New batch
# tensor(0.2378, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4838407039642334
# Time loading: 0.0007596015930175781
# New batch
# tensor(0.4574, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45449280738830566
# Time loading: 0.0019903182983398438
# New batch
# tensor(0.3973, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45708179473876953
# Time loading: 0.00037479400634765625
# New batch
# tensor(0.3373, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5083184242248535
# Time loading: 0.0004723072052001953
# New batch
# tensor(0.3467, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4896104335784912
# Time loading: 0.0004363059997558594
# New batch
# tensor(0.1445, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45825958251953125
# Time loading: 0.0021126270294189453
# New batch
# tensor(0.4090, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46792054176330566
# Time loading: 0.00033211708068847656
# New batch
# tensor(0.3353, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46960902214050293
# Time loading: 0.0005469322204589844
# New batch
# tensor(0.3518, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5333986282348633
# Time loading: 2.8026976585388184
# New batch
# tensor(0.3082, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5935437679290771
# Time loading: 0.0002148151397705078
# New batch
# tensor(0.4862, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4743504524230957
# Time loading: 0.0010352134704589844
# New batch
# tensor(0.1438, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4648013114929199
# Time loading: 0.0010709762573242188
# New batch
# tensor(0.4134, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4676494598388672
# Time loading: 0.00179290771484375
# New batch
# tensor(0.4376, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45928335189819336
# Time loading: 4.519443511962891
# New batch
# tensor(0.3128, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5221068859100342
# Time loading: 0.0007364749908447266
# New batch
# tensor(0.1767, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45654726028442383
# Time loading: 0.0002028942108154297
# New batch
# tensor(0.3798, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46535444259643555
# Time loading: 0.0007576942443847656
# New batch
# tensor(0.3774, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45718979835510254
# Time loading: 0.00029850006103515625
# New batch
# tensor(0.3478, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46042704582214355
# Time loading: 0.0007312297821044922
# New batch
# tensor(0.2898, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4568607807159424
# Time loading: 0.0003361701965332031
# New batch
# tensor(0.3311, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4882376194000244
# Time loading: 0.0002262592315673828
# New batch
# tensor(0.3022, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46418333053588867
# Time loading: 0.0001957416534423828
# New batch
# tensor(0.3303, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4688727855682373
# Time loading: 0.004174947738647461
# New batch
# tensor(0.4525, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4756166934967041
# Time loading: 0.00032401084899902344
# New batch
# tensor(0.2044, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46509480476379395
# Time loading: 5.147116184234619
# New batch
# tensor(0.2136, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5112264156341553
# Time loading: 0.0007302761077880859
# New batch
# tensor(0.3773, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45540809631347656
# Time loading: 0.0009822845458984375
# New batch
# tensor(0.1680, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4681708812713623
# Time loading: 0.0012056827545166016
# New batch
# tensor(0.1982, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4529731273651123
# Time loading: 0.28206753730773926
# New batch
# tensor(0.1385, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4641852378845215
# Time loading: 4.327872037887573
# New batch
# tensor(0.4223, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5408158302307129
# Time loading: 0.00032711029052734375
# New batch
# tensor(0.3320, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4615349769592285
# Time loading: 0.0006351470947265625
# New batch
# tensor(0.3794, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46395087242126465
# Time loading: 0.0015461444854736328
# New batch
# tensor(0.3750, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4720785617828369
# Time loading: 0.0018939971923828125
# New batch
# tensor(0.4860, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.474668025970459
# Time loading: 0.0001392364501953125
# New batch
# tensor(0.3133, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5270836353302002
# Time loading: 0.0018150806427001953
# New batch
# tensor(0.1927, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48766112327575684
# Time loading: 0.0007090568542480469
# New batch
# tensor(0.4069, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4535801410675049
# Time loading: 0.0001926422119140625
# New batch
# tensor(0.3438, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45827460289001465
# Time loading: 0.0006668567657470703
# New batch
# tensor(0.4502, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45360612869262695
# Time loading: 0.0008151531219482422
# New batch
# tensor(0.2452, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45835137367248535
# Time loading: 3.817497968673706
# New batch
# tensor(0.4257, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5402491092681885
# Time loading: 0.0001671314239501953
# New batch
# tensor(0.2055, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4572913646697998
# Time loading: 0.00013566017150878906
# New batch
# tensor(0.3739, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48322033882141113
# Time loading: 0.0001494884490966797
# New batch
# tensor(0.1587, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4827308654785156
# Time loading: 0.0025773048400878906
# New batch
# tensor(0.3961, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.467456579208374
# Time loading: 2.7092113494873047
# New batch
# tensor(0.3138, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5110454559326172
# Time loading: 0.000370025634765625
# New batch
# tensor(0.4010, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46075963973999023
# Time loading: 0.0006024837493896484
# New batch
# tensor(0.2413, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4618964195251465
# Time loading: 0.0001404285430908203
# New batch
# tensor(0.3393, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45705223083496094
# Time loading: 0.000934600830078125
# New batch
# tensor(0.1933, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46434807777404785
# Time loading: 0.00024175643920898438
# New batch
# tensor(0.3073, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46856021881103516
# Time loading: 0.00014090538024902344
# New batch
# tensor(0.5254, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46236491203308105
# Time loading: 0.00023126602172851562
# New batch
# tensor(0.3516, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4570791721343994
# Time loading: 0.005270957946777344
# New batch
# tensor(0.4441, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4605867862701416
# Time loading: 0.000164031982421875
# New batch
# tensor(0.2769, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4582247734069824
# Time loading: 0.00013184547424316406
# New batch
# tensor(0.2597, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46165943145751953
# Time loading: 0.34434032440185547
# New batch
# tensor(0.3510, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)

# %%
for param in model_conv.parameters():
    param.requires_grad = True

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,
                         exp_lr_scheduler, {"train": train_dataloader, "val": test_dataloader}, num_epochs=24)
# Out:
# Epoch 0/23
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Streaming output truncated to the last 5000 lines.
# Time loading: 0.0016338825225830078
# New batch
# tensor(0.3385, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48060083389282227
# Time loading: 0.00030541419982910156
# New batch
# tensor(0.4187, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46369004249572754
# Time loading: 0.0007634162902832031
# New batch
# tensor(0.4256, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46623754501342773
# Time loading: 0.0003173351287841797
# New batch
# tensor(0.5053, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.498157262802124
# Time loading: 0.0025641918182373047
# New batch
# tensor(0.3832, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4684000015258789
# Time loading: 0.006111860275268555
# New batch
# tensor(0.3337, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4751150608062744
# Time loading: 0.002981901168823242
# New batch
# tensor(0.4978, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46312737464904785
# Time loading: 0.0008528232574462891
# New batch
# tensor(0.4534, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4632577896118164
# Time loading: 0.0008749961853027344
# New batch
# tensor(0.3699, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4637939929962158
# Time loading: 0.0009160041809082031
# New batch
# tensor(0.3589, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48180460929870605
# Time loading: 8.960521936416626
# New batch
# tensor(0.3696, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5477440357208252
# Time loading: 0.00031828880310058594
# New batch
# tensor(0.4925, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47157812118530273
# Time loading: 0.0009927749633789062
# New batch
# tensor(0.4881, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4611184597015381
# Time loading: 0.0010418891906738281
# New batch
# tensor(0.4561, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4630141258239746
# Time loading: 0.0005841255187988281
# New batch
# tensor(0.6290, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46508097648620605
# Time loading: 0.001127481460571289
# New batch
# tensor(0.3668, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46764445304870605
# Time loading: 0.0003676414489746094
# New batch
# tensor(0.4464, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4697408676147461
# Time loading: 0.0008840560913085938
# New batch
# tensor(0.5155, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4799785614013672
# Time loading: 0.0008859634399414062
# New batch
# tensor(0.4361, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.468461275100708
# Time loading: 0.00078582763671875
# New batch
# tensor(0.4458, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4682271480560303
# Time loading: 0.02029585838317871
# New batch
# tensor(0.4901, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4960594177246094
# Time loading: 0.0008428096771240234
# New batch
# tensor(0.4713, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4601321220397949
# Time loading: 0.006227016448974609
# New batch
# tensor(0.4943, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.49875855445861816
# Time loading: 0.00098419189453125
# New batch
# tensor(0.3346, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4665656089782715
# Time loading: 0.0018045902252197266
# New batch
# tensor(0.4374, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47210168838500977
# Time loading: 0.0009007453918457031
# New batch
# tensor(0.4106, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.460036039352417
# Time loading: 7.254205942153931
# New batch
# tensor(0.4139, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5109982490539551
# Time loading: 0.0006327629089355469
# New batch
# tensor(0.4271, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.526378870010376
# Time loading: 0.004764556884765625
# New batch
# tensor(0.5123, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4631674289703369
# Time loading: 0.002203702926635742
# New batch
# tensor(0.3900, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46213197708129883
# Time loading: 0.00069427490234375
# New batch
# tensor(0.3975, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4558999538421631
# Time loading: 0.0009465217590332031
# New batch
# tensor(0.4094, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.461073637008667
# Time loading: 0.0008208751678466797
# New batch
# tensor(0.3473, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4608192443847656
# Time loading: 0.0006167888641357422
# New batch
# tensor(0.4463, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4721207618713379
# Time loading: 0.000202178955078125
# New batch
# tensor(0.3240, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4810168743133545
# Time loading: 0.0007221698760986328
# New batch
# tensor(0.4130, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4647488594055176
# Time loading: 0.0028104782104492188
# New batch
# tensor(0.3468, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5116567611694336
# Time loading: 0.00035691261291503906
# New batch
# tensor(0.4305, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46038365364074707
# Time loading: 3.493020534515381
# New batch
# tensor(0.3827, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5256137847900391
# Time loading: 0.0009350776672363281
# New batch
# tensor(0.3148, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45639491081237793
# Time loading: 0.001062631607055664
# New batch
# tensor(0.4248, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.478743314743042
# Time loading: 0.0006194114685058594
# New batch
# tensor(0.4451, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46274781227111816
# Time loading: 3.6997714042663574
# New batch
# tensor(0.3968, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5264391899108887
# Time loading: 0.00022149085998535156
# New batch
# tensor(0.5322, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4889652729034424
# Time loading: 3.281067132949829
# New batch
# tensor(0.3120, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5131890773773193
# Time loading: 0.03478693962097168
# New batch
# tensor(0.4772, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46146678924560547
# Time loading: 0.0019218921661376953
# New batch
# tensor(0.3843, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.520427942276001
# Time loading: 0.0009763240814208984
# New batch
# tensor(0.3410, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46175169944763184
# Time loading: 0.0022482872009277344
# New batch
# tensor(0.4367, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4652552604675293
# Time loading: 0.000408172607421875
# New batch
# tensor(0.3904, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.49360036849975586
# Time loading: 0.00019884109497070312
# New batch
# tensor(0.6481, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47821617126464844
# Time loading: 0.0004124641418457031
# New batch
# tensor(0.4698, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4703855514526367
# Time loading: 0.0008656978607177734
# New batch
# tensor(0.4214, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4748053550720215
# Time loading: 0.00036716461181640625
# New batch
# tensor(0.3378, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.514413595199585
# Time loading: 0.0021071434020996094
# New batch
# tensor(0.4597, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5150830745697021
# Time loading: 0.0003361701965332031
# New batch
# tensor(0.4720, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.465893030166626
# Time loading: 0.0007908344268798828
# New batch
# tensor(0.4774, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46056413650512695
# Time loading: 0.0007436275482177734
# New batch
# tensor(0.4606, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4875164031982422
# Time loading: 8.329575538635254
# New batch
# tensor(0.4188, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5192077159881592
# Time loading: 0.0007340908050537109
# New batch
# tensor(0.4070, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46477842330932617
# Time loading: 0.24016427993774414
# New batch
# tensor(0.4382, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4624960422515869
# Time loading: 0.0002319812774658203
# New batch
# tensor(0.4448, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48758506774902344
# Time loading: 0.0003058910369873047
# New batch
# tensor(0.4258, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46133899688720703
# Time loading: 0.00018215179443359375
# New batch
# tensor(0.5014, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46068644523620605
# Time loading: 0.0024051666259765625
# New batch
# tensor(0.3098, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4617328643798828
# Time loading: 0.0010805130004882812
# New batch
# tensor(0.2549, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5050323009490967
# Time loading: 0.0009052753448486328
# New batch
# tensor(0.4257, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46061205863952637
# Time loading: 0.000774383544921875
# New batch
# tensor(0.4659, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4752030372619629
# Time loading: 0.00034356117248535156
# New batch
# tensor(0.3249, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47887182235717773
# Time loading: 0.008618593215942383
# New batch
# tensor(0.4301, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4828824996948242
# Time loading: 0.0018303394317626953
# New batch
# tensor(0.3673, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47088170051574707
# Time loading: 0.0003948211669921875
# New batch
# tensor(0.3476, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48032641410827637
# Time loading: 0.00037169456481933594
# New batch
# tensor(0.2589, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46253252029418945
# Time loading: 0.00044465065002441406
# New batch
# tensor(0.4182, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4623758792877197
# Time loading: 3.8933165073394775
# New batch
# tensor(0.3833, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5494840145111084
# Time loading: 0.0009329319000244141
# New batch
# tensor(0.3759, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46224236488342285
# Time loading: 4.996052026748657
# New batch
# tensor(0.5527, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5172739028930664
# Time loading: 0.005054473876953125
# New batch
# tensor(0.4919, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.6062180995941162
# Time loading: 0.0008137226104736328
# New batch
# tensor(0.4326, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5027937889099121
# Time loading: 0.0036013126373291016
# New batch
# tensor(0.4307, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4859156608581543
# Time loading: 0.002116680145263672
# New batch
# tensor(0.4581, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4669225215911865
# Time loading: 0.0001742839813232422
# New batch
# tensor(0.3803, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46865177154541016
# Time loading: 0.000347137451171875
# New batch
# tensor(0.4405, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4699990749359131
# Time loading: 0.005829334259033203
# New batch
# tensor(0.4450, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4755361080169678
# Time loading: 0.0009033679962158203
# New batch
# tensor(0.4218, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4625387191772461
# Time loading: 0.003947257995605469
# New batch
# tensor(0.5058, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46979761123657227
# Time loading: 0.012408733367919922
# New batch
# tensor(0.5009, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4691190719604492
# Time loading: 0.0001995563507080078
# New batch
# tensor(0.3830, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46447277069091797
# Time loading: 0.0004744529724121094
# New batch
# tensor(0.4904, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5109543800354004
# Time loading: 0.0003254413604736328
# New batch
# tensor(0.3210, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4661428928375244
# Time loading: 3.9587202072143555
# New batch
# tensor(0.4430, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5267579555511475
# Time loading: 0.0008552074432373047
# New batch
# tensor(0.3501, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46480798721313477
# Time loading: 1.285698413848877
# New batch
# tensor(0.4968, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4640829563140869
# Time loading: 0.0005660057067871094
# New batch
# tensor(0.2646, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.464893102645874
# Time loading: 0.0010528564453125
# New batch
# tensor(0.5114, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46039557456970215
# Time loading: 0.0008740425109863281
# New batch
# tensor(0.3842, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.463864803314209
# Time loading: 0.003625154495239258
# New batch
# tensor(0.4866, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4629075527191162
# Time loading: 0.0008213520050048828
# New batch
# tensor(0.4205, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4646642208099365
# Time loading: 0.0005097389221191406
# New batch
# tensor(0.3073, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47637486457824707
# Time loading: 0.0008630752563476562
# New batch
# tensor(0.4900, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46551942825317383
# Time loading: 0.0009834766387939453
# New batch
# tensor(0.4653, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4839468002319336
# Time loading: 0.0006778240203857422
# New batch
# tensor(0.4363, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47547364234924316
# Time loading: 0.757887601852417
# New batch
# tensor(0.3456, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.49025535583496094
# Time loading: 0.0009925365447998047
# New batch
# tensor(0.2644, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46199846267700195
# Time loading: 0.00034046173095703125
# New batch
# tensor(0.2982, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47466111183166504
# Time loading: 0.0016126632690429688
# New batch
# tensor(0.4984, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4654719829559326
# Time loading: 7.577489852905273
# New batch
# tensor(0.4795, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.510554313659668
# Time loading: 0.0010044574737548828
# New batch
# tensor(0.4870, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46582484245300293
# Time loading: 0.49939465522766113
# New batch
# tensor(0.6818, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47127556800842285
# Time loading: 0.002732515335083008
# New batch
# tensor(0.3048, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48276329040527344
# Time loading: 0.0006895065307617188
# New batch
# tensor(0.4599, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4728822708129883
# Time loading: 0.0009431838989257812
# New batch
# tensor(0.5994, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45807600021362305
# Time loading: 0.002277851104736328
# New batch
# tensor(0.3922, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4577665328979492
# Time loading: 0.0007748603820800781
# New batch
# tensor(0.5565, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46064233779907227
# Time loading: 0.0008616447448730469
# New batch
# tensor(0.3898, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4634404182434082
# Time loading: 0.0007166862487792969
# New batch
# tensor(0.3330, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45975255966186523
# Time loading: 0.001058340072631836
# New batch
# tensor(0.3976, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45702433586120605
# Time loading: 0.0007283687591552734
# New batch
# tensor(0.3832, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4589228630065918
# Time loading: 3.012883186340332
# New batch
# tensor(0.4644, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5436899662017822
# Time loading: 0.002957582473754883
# New batch
# tensor(0.4339, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.52939772605896
# Time loading: 0.0006518363952636719
# New batch
# tensor(0.5492, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5099084377288818
# Time loading: 0.00052642822265625
# New batch
# tensor(0.4373, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47492003440856934
# Time loading: 4.473684787750244
# New batch
# tensor(0.3434, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.509289026260376
# Time loading: 0.0009541511535644531
# New batch
# tensor(0.4418, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4750196933746338
# Time loading: 1.5390334129333496
# New batch
# tensor(0.3920, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4582488536834717
# Time loading: 0.0004215240478515625
# New batch
# tensor(0.4825, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.465451717376709
# Time loading: 0.0003757476806640625
# New batch
# tensor(0.2801, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48274683952331543
# Time loading: 0.0009887218475341797
# New batch
# tensor(0.3987, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46787285804748535
# Time loading: 0.0036401748657226562
# New batch
# tensor(0.3666, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4642064571380615
# Time loading: 0.0009450912475585938
# New batch
# tensor(0.4311, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47504305839538574
# Time loading: 0.0001933574676513672
# New batch
# tensor(0.4217, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46463942527770996
# Time loading: 0.0001735687255859375
# New batch
# tensor(0.4627, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4651501178741455
# Time loading: 0.00030231475830078125
# New batch
# tensor(0.5016, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4732050895690918
# Time loading: 0.002790212631225586
# New batch
# tensor(0.2418, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.495913028717041
# Time loading: 1.4761712551116943
# New batch
# tensor(0.4442, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46349287033081055
# Time loading: 0.0007460117340087891
# New batch
# tensor(0.3800, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45949721336364746
# Time loading: 0.0008671283721923828
# New batch
# tensor(0.4042, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4630727767944336
# Time loading: 0.0001747608184814453
# New batch
# tensor(0.3052, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46274876594543457
# Time loading: 6.5152881145477295
# New batch
# tensor(0.4509, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5337104797363281
# Time loading: 0.0008637905120849609
# New batch
# tensor(0.3588, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45896458625793457
# Time loading: 3.1079063415527344
# New batch
# tensor(0.3760, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5050640106201172
# Time loading: 0.003851652145385742
# New batch
# tensor(0.4883, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4612419605255127
# Time loading: 0.0015981197357177734
# New batch
# tensor(0.6015, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4734642505645752
# Time loading: 0.0010540485382080078
# New batch
# tensor(0.5453, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4676239490509033
# Time loading: 0.00018739700317382812
# New batch
# tensor(0.3630, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.460726261138916
# Time loading: 0.00033283233642578125
# New batch
# tensor(0.4392, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.49196314811706543
# Time loading: 0.0003609657287597656
# New batch
# tensor(0.4099, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.49131059646606445
# Time loading: 0.0009377002716064453
# New batch
# tensor(0.3524, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48874521255493164
# Time loading: 0.0037109851837158203
# New batch
# tensor(0.3412, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4655895233154297
# Time loading: 0.0009560585021972656
# New batch
# tensor(0.5293, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4630160331726074
# Time loading: 0.0020761489868164062
# New batch
# tensor(0.3563, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46282482147216797
# Time loading: 0.0023527145385742188
# New batch
# tensor(0.2697, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4676506519317627
# Time loading: 0.0007565021514892578
# New batch
# tensor(0.3692, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46178174018859863
# Time loading: 0.0008039474487304688
# New batch
# tensor(0.3579, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46004796028137207
# Time loading: 6.792079210281372
# New batch
# tensor(0.3112, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5319066047668457
# Time loading: 0.0008373260498046875
# New batch
# tensor(0.4053, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4891195297241211
# Time loading: 0.00162506103515625
# New batch
# tensor(0.3170, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46202516555786133
# Time loading: 0.0036940574645996094
# New batch
# tensor(0.3725, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46241307258605957
# Time loading: 0.0008440017700195312
# New batch
# tensor(0.4598, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46884727478027344
# Time loading: 0.0011887550354003906
# New batch
# tensor(0.3804, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47472310066223145
# Time loading: 0.0023725032806396484
# New batch
# tensor(0.6318, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4639871120452881
# Time loading: 0.00040459632873535156
# New batch
# tensor(0.3504, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.467531681060791
# Time loading: 0.0009784698486328125
# New batch
# tensor(0.3454, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46862149238586426
# Time loading: 0.0003380775451660156
# New batch
# tensor(0.4891, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4641151428222656
# Time loading: 0.005428791046142578
# New batch
# tensor(0.3911, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4788022041320801
# Time loading: 0.0008783340454101562
# New batch
# tensor(0.3558, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4661586284637451
# Time loading: 1.6097497940063477
# New batch
# tensor(0.5191, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46223950386047363
# Time loading: 0.0009195804595947266
# New batch
# tensor(0.5213, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4690206050872803
# Time loading: 0.0001780986785888672
# New batch
# tensor(0.5847, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46366024017333984
# Time loading: 0.0007610321044921875
# New batch
# tensor(0.4919, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46545934677124023
# Time loading: 8.03012728691101
# New batch
# tensor(0.6295, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5194907188415527
# Time loading: 0.0003273487091064453
# New batch
# tensor(0.4089, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48311376571655273
# Time loading: 0.009247064590454102
# New batch
# tensor(0.5637, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47446131706237793
# Time loading: 0.003317117691040039
# New batch
# tensor(0.8372, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4652061462402344
# Time loading: 0.0009512901306152344
# New batch
# tensor(0.3007, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47325658798217773
# Time loading: 0.0005266666412353516
# New batch
# tensor(0.4747, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4731481075286865
# Time loading: 0.0022728443145751953
# New batch
# tensor(0.3922, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4622068405151367
# Time loading: 0.0038421154022216797
# New batch
# tensor(0.4457, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5100088119506836
# Time loading: 0.0005364418029785156
# New batch
# tensor(0.4003, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4644432067871094
# Time loading: 0.00020360946655273438
# New batch
# tensor(0.4302, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4893159866333008
# Time loading: 0.0009484291076660156
# New batch
# tensor(0.4073, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4808650016784668
# Time loading: 0.0009942054748535156
# New batch
# tensor(0.3502, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46456003189086914
# Time loading: 0.28457045555114746
# New batch
# tensor(0.5423, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.464184045791626
# Time loading: 0.00041937828063964844
# New batch
# tensor(0.3219, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46686506271362305
# Time loading: 0.0013027191162109375
# New batch
# tensor(0.4503, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4636707305908203
# Time loading: 0.0002186298370361328
# New batch
# tensor(0.5047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4668610095977783
# Time loading: 4.402435779571533
# New batch
# tensor(0.5475, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5055699348449707
# Time loading: 0.00043702125549316406
# New batch
# tensor(0.4396, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4626739025115967
# Time loading: 2.1531336307525635
# New batch
# tensor(0.3608, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5348293781280518
# Time loading: 0.12479019165039062
# New batch
# tensor(0.3907, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.461503267288208
# Time loading: 0.00031375885009765625
# New batch
# tensor(0.4935, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4665529727935791
# Time loading: 0.0009107589721679688
# New batch
# tensor(0.2570, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46486425399780273
# Time loading: 0.0022034645080566406
# New batch
# tensor(0.4745, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4634113311767578
# Time loading: 0.00020933151245117188
# New batch
# tensor(0.3882, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4664270877838135
# Time loading: 0.0013697147369384766
# New batch
# tensor(0.3982, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4655721187591553
# Time loading: 0.0005464553833007812
# New batch
# tensor(0.4580, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4624974727630615
# Time loading: 0.0007758140563964844
# New batch
# tensor(0.5415, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4609675407409668
# Time loading: 0.000766754150390625
# New batch
# tensor(0.3396, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4611940383911133
# Time loading: 3.7215073108673096
# New batch
# tensor(0.3325, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5269160270690918
# Time loading: 0.0010881423950195312
# New batch
# tensor(0.3570, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4645092487335205
# Time loading: 0.0010073184967041016
# New batch
# tensor(0.4644, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4638347625732422
# Time loading: 0.00023794174194335938
# New batch
# tensor(0.3149, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4718916416168213
# Time loading: 3.4510135650634766
# New batch
# tensor(0.3897, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5312821865081787
# Time loading: 0.0008981227874755859
# New batch
# tensor(0.4051, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4605112075805664
# Time loading: 2.720515727996826
# New batch
# tensor(0.4121, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5606718063354492
# Time loading: 0.0010907649993896484
# New batch
# tensor(0.3940, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4576704502105713
# Time loading: 0.0007755756378173828
# New batch
# tensor(0.5196, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45886850357055664
# Time loading: 0.0006499290466308594
# New batch
# tensor(0.4074, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4613940715789795
# Time loading: 0.0031511783599853516
# New batch
# tensor(0.4845, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4580988883972168
# Time loading: 0.00016736984252929688
# New batch
# tensor(0.4503, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4602084159851074
# Time loading: 0.0007309913635253906
# New batch
# tensor(0.3223, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4593944549560547
# Time loading: 0.0005795955657958984
# New batch
# tensor(0.3868, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48085784912109375
# Time loading: 0.0008389949798583984
# New batch
# tensor(0.5418, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45839691162109375
# Time loading: 0.0008902549743652344
# New batch
# tensor(0.2989, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4725463390350342
# Time loading: 2.556683301925659
# New batch
# tensor(0.2509, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5171706676483154
# Time loading: 0.002173900604248047
# New batch
# tensor(0.4308, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.49166202545166016
# Time loading: 0.0008788108825683594
# New batch
# tensor(0.4473, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4634087085723877
# Time loading: 0.0007531642913818359
# New batch
# tensor(0.2896, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46476125717163086
# Time loading: 3.370249032974243
# New batch
# tensor(0.3598, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5444133281707764
# Time loading: 0.0003814697265625
# New batch
# tensor(0.3489, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4604923725128174
# Time loading: 1.3542447090148926
# New batch
# tensor(0.3946, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4583628177642822
# Time loading: 0.0008881092071533203
# New batch
# tensor(0.4654, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4638221263885498
# Time loading: 0.0020532608032226562
# New batch
# tensor(0.4095, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46544766426086426
# Time loading: 0.00032138824462890625
# New batch
# tensor(0.4826, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4609804153442383
# Time loading: 0.6075093746185303
# New batch
# tensor(0.3937, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46155548095703125
# Time loading: 0.000896453857421875
# New batch
# tensor(0.4016, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4677269458770752
# Time loading: 0.0008714199066162109
# New batch
# tensor(0.5154, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4625990390777588
# Time loading: 0.0006229877471923828
# New batch
# tensor(0.3725, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4637420177459717
# Time loading: 0.0002090930938720703
# New batch
# tensor(0.4042, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47989940643310547
# Time loading: 0.0009756088256835938
# New batch
# tensor(0.2593, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4605729579925537
# Time loading: 2.9317758083343506
# New batch
# tensor(0.4267, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5309841632843018
# Time loading: 0.0002086162567138672
# New batch
# tensor(0.4543, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46392822265625
# Time loading: 0.0007991790771484375
# New batch
# tensor(0.3890, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4608914852142334
# Time loading: 0.00020885467529296875
# New batch
# tensor(0.4101, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4791243076324463
# Time loading: 4.782531261444092
# New batch
# tensor(0.6455, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5361711978912354
# Time loading: 0.0003848075866699219
# New batch
# tensor(0.4856, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4709312915802002
# Time loading: 0.35126519203186035
# New batch
# tensor(0.4240, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4587893486022949
# Time loading: 0.0004718303680419922
# New batch
# tensor(0.4086, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4641435146331787
# Time loading: 0.0002903938293457031
# New batch
# tensor(0.3840, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.49849820137023926
# Time loading: 0.0009276866912841797
# New batch
# tensor(0.6944, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46589136123657227
# Time loading: 0.0032532215118408203
# New batch
# tensor(0.5020, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4625430107116699
# Time loading: 0.0003991127014160156
# New batch
# tensor(0.4204, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.464611291885376
# Time loading: 0.000823974609375
# New batch
# tensor(0.3688, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4617805480957031
# Time loading: 0.00089263916015625
# New batch
# tensor(0.3761, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4597816467285156
# Time loading: 0.000993967056274414
# New batch
# tensor(0.4565, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46063876152038574
# Time loading: 0.0002593994140625
# New batch
# tensor(0.5194, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46456432342529297
# Time loading: 6.970491409301758
# New batch
# tensor(0.3837, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.546076774597168
# Time loading: 0.0012633800506591797
# New batch
# tensor(0.3426, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4772481918334961
# Time loading: 0.0010955333709716797
# New batch
# tensor(0.3934, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47704386711120605
# Time loading: 0.0013082027435302734
# New batch
# tensor(0.7974, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47375035285949707
# Time loading: 1.1885559558868408
# New batch
# tensor(0.6002, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4662814140319824
# Time loading: 0.00042819976806640625
# New batch
# tensor(0.4528, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4638855457305908
# Time loading: 0.5305836200714111
# New batch
# tensor(0.3572, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47022414207458496
# Time loading: 0.0033636093139648438
# New batch
# tensor(0.3345, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.465437650680542
# Time loading: 0.008713722229003906
# New batch
# tensor(0.3664, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.469940185546875
# Time loading: 0.0009474754333496094
# New batch
# tensor(0.4574, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45792102813720703
# Time loading: 2.6979150772094727
# New batch
# tensor(0.3610, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5089893341064453
# Time loading: 0.0002963542938232422
# New batch
# tensor(0.5078, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45905327796936035
# Time loading: 0.0013532638549804688
# New batch
# tensor(0.5448, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48281335830688477
# Time loading: 0.00045990943908691406
# New batch
# tensor(0.4650, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4677393436431885
# Time loading: 0.0012331008911132812
# New batch
# tensor(0.4189, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4675862789154053
# Time loading: 0.0007545948028564453
# New batch
# tensor(0.5404, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.460040807723999
# Time loading: 1.7009527683258057
# New batch
# tensor(0.5826, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.52394700050354
# Time loading: 0.0008707046508789062
# New batch
# tensor(0.2130, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4697093963623047
# Time loading: 0.002260923385620117
# New batch
# tensor(0.4447, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4960751533508301
# Time loading: 0.0005486011505126953
# New batch
# tensor(0.4359, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4634537696838379
# Time loading: 4.814435005187988
# New batch
# tensor(0.4864, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5828063488006592
# Time loading: 0.00030875205993652344
# New batch
# tensor(0.5043, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48507022857666016
# Time loading: 0.6415808200836182
# New batch
# tensor(0.3359, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4850630760192871
# Time loading: 0.0005209445953369141
# New batch
# tensor(0.2483, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46163082122802734
# Time loading: 0.0002853870391845703
# New batch
# tensor(0.4529, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4671974182128906
# Time loading: 0.000484466552734375
# New batch
# tensor(0.4907, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.49344444274902344
# Time loading: 0.006793975830078125
# New batch
# tensor(0.3518, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46495866775512695
# Time loading: 0.0006787776947021484
# New batch
# tensor(0.4529, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4660909175872803
# Time loading: 0.00025582313537597656
# New batch
# tensor(0.3803, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46356892585754395
# Time loading: 0.0003268718719482422
# New batch
# tensor(0.4963, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47501277923583984
# Time loading: 0.0009729862213134766
# New batch
# tensor(0.3591, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46312475204467773
# Time loading: 0.0001862049102783203
# New batch
# tensor(0.3273, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4640069007873535
# Time loading: 4.016944885253906
# New batch
# tensor(0.4634, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.506777286529541
# Time loading: 0.0011205673217773438
# New batch
# tensor(0.4410, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.49156856536865234
# Time loading: 0.0006513595581054688
# New batch
# tensor(0.3086, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4681415557861328
# Time loading: 0.000926971435546875
# New batch
# tensor(0.4970, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46583032608032227
# Time loading: 1.5275657176971436
# New batch
# tensor(0.4381, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4789130687713623
# Time loading: 0.0004565715789794922
# New batch
# tensor(0.5531, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4607365131378174
# Time loading: 0.8315613269805908
# New batch
# tensor(0.3218, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45856642723083496
# Time loading: 0.0001888275146484375
# New batch
# tensor(0.3799, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4711644649505615
# Time loading: 0.0003178119659423828
# New batch
# tensor(0.3342, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4673023223876953
# Time loading: 0.0001857280731201172
# New batch
# tensor(0.3344, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45934200286865234
# Time loading: 0.0036573410034179688
# New batch
# tensor(0.4598, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4703657627105713
# Time loading: 0.0007488727569580078
# New batch
# tensor(0.4685, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46480298042297363
# Time loading: 0.0009849071502685547
# New batch
# tensor(0.3132, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4651224613189697
# Time loading: 0.001111745834350586
# New batch
# tensor(0.3880, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4743070602416992
# Time loading: 0.0006937980651855469
# New batch
# tensor(0.6243, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4638512134552002
# Time loading: 0.00019240379333496094
# New batch
# tensor(0.3606, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46289944648742676
# Time loading: 7.132819414138794
# New batch
# tensor(0.3808, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5522527694702148
# Time loading: 0.0003750324249267578
# New batch
# ...
# Time executing: 0.48285841941833496
# Time loading: 0.00018978118896484375
# New batch
# tensor(0.6562, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4616823196411133
# Time loading: 0.008040189743041992
# New batch
# tensor(0.4075, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4620356559753418
# Time loading: 0.00019812583923339844
# New batch
# tensor(0.4479, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46195340156555176
# Time loading: 0.0012500286102294922
# New batch
# tensor(0.5054, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46308374404907227
# Time loading: 0.0009467601776123047
# New batch
# tensor(0.3720, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4640073776245117
# Time loading: 0.001087188720703125
# New batch
# tensor(0.3856, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47370290756225586
# Time loading: 0.0002231597900390625
# New batch
# tensor(0.4771, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4638230800628662
# Time loading: 0.0006344318389892578
# New batch
# tensor(0.3543, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4646778106689453
# Time loading: 0.0010821819305419922
# New batch
# tensor(0.4402, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4722108840942383
# Time loading: 7.058727025985718
# New batch
# tensor(0.6142, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5975058078765869
# Time loading: 2.750497341156006
# New batch
# tensor(0.3427, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5188133716583252
# Time loading: 0.0008881092071533203
# New batch
# tensor(0.6168, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.465900182723999
# Time loading: 0.00033783912658691406
# New batch
# tensor(0.4638, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4653630256652832
# Time loading: 0.0009331703186035156
# New batch
# tensor(0.3961, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45935654640197754
# Time loading: 0.0005929470062255859
# New batch
# tensor(0.4915, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46060752868652344
# Time loading: 0.00033164024353027344
# New batch
# tensor(0.2743, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.490062952041626
# Time loading: 0.00021219253540039062
# New batch
# tensor(0.3937, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48093438148498535
# Time loading: 0.0021147727966308594
# New batch
# tensor(0.4223, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46012353897094727
# Time loading: 0.0007426738739013672
# New batch
# tensor(0.5949, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4659440517425537
# Time loading: 0.0010623931884765625
# New batch
# tensor(0.4894, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4613199234008789
# Time loading: 0.00021147727966308594
# New batch
# tensor(0.4719, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4682612419128418
# Time loading: 0.0009944438934326172
# New batch
# tensor(0.4541, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4646263122558594
# Time loading: 0.000835418701171875
# New batch
# tensor(0.4589, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4637186527252197
# Time loading: 0.0001964569091796875
# New batch
# tensor(0.5265, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4628565311431885
# Time loading: 0.0009775161743164062
# New batch
# tensor(0.6256, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46568846702575684
# Time loading: 5.022284269332886
# New batch
# tensor(0.3998, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.53489089012146
# Time loading: 2.7486021518707275
# New batch
# tensor(0.2853, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5200300216674805
# Time loading: 0.00035691261291503906
# New batch
# tensor(0.4901, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5001602172851562
# Time loading: 0.0013689994812011719
# New batch
# tensor(0.3797, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46017980575561523
# Time loading: 0.00017070770263671875
# New batch
# tensor(0.3476, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4620354175567627
# Time loading: 0.0009510517120361328
# New batch
# tensor(0.4535, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46564483642578125
# Time loading: 0.00023245811462402344
# New batch
# tensor(0.4520, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46665287017822266
# Time loading: 0.0007562637329101562
# New batch
# tensor(0.4611, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4634721279144287
# Time loading: 0.0009157657623291016
# New batch
# tensor(0.4303, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46361303329467773
# Time loading: 0.0021927356719970703
# New batch
# tensor(0.4132, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47997140884399414
# Time loading: 0.0008409023284912109
# New batch
# tensor(0.5979, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46320199966430664
# Time loading: 0.0011644363403320312
# New batch
# tensor(0.5029, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47034621238708496
# Time loading: 0.0008025169372558594
# New batch
# tensor(0.3854, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46503329277038574
# Time loading: 0.0008740425109863281
# New batch
# tensor(0.5234, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4698169231414795
# Time loading: 0.0009753704071044922
# New batch
# tensor(0.4404, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46528029441833496
# Time loading: 0.0007116794586181641
# New batch
# tensor(0.2214, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4673118591308594
# Time loading: 2.152097463607788
# New batch
# tensor(0.4453, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5297179222106934
# Time loading: 4.996064186096191
# New batch
# tensor(0.4647, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5281047821044922
# Time loading: 0.00036334991455078125
# New batch
# tensor(0.3927, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47673940658569336
# Time loading: 0.00022602081298828125
# New batch
# tensor(0.4401, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4658052921295166
# Time loading: 0.0004723072052001953
# New batch
# tensor(0.5072, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47420644760131836
# Time loading: 0.00028824806213378906
# New batch
# tensor(0.3697, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4631953239440918
# Time loading: 0.0002720355987548828
# New batch
# tensor(0.5812, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4674530029296875
# Time loading: 0.003350496292114258
# New batch
# tensor(0.5040, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4655110836029053
# Time loading: 0.002107381820678711
# New batch
# tensor(0.3945, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46352171897888184
# Time loading: 0.0003719329833984375
# New batch
# tensor(1.0054, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4663412570953369
# Time loading: 0.013088703155517578
# New batch
# tensor(0.3694, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47975921630859375
# Time loading: 0.000995635986328125
# New batch
# tensor(0.4250, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4799165725708008
# Time loading: 0.002354145050048828
# New batch
# tensor(0.3864, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4629096984863281
# Time loading: 0.0003409385681152344
# New batch
# tensor(0.5442, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48273754119873047
# Time loading: 0.0005576610565185547
# New batch
# tensor(0.3865, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45911622047424316
# Time loading: 0.00016927719116210938
# New batch
# tensor(0.4550, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4600045680999756
# Time loading: 4.689010143280029
# New batch
# tensor(0.4767, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5321207046508789
# Time loading: 2.9022035598754883
# New batch
# tensor(0.3626, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.541163444519043
# Time loading: 0.0007755756378173828
# New batch
# tensor(0.3024, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4652113914489746
# Time loading: 0.0008296966552734375
# New batch
# tensor(0.3451, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.455721378326416
# Time loading: 0.0009529590606689453
# New batch
# tensor(0.4513, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45917797088623047
# Time loading: 0.0007107257843017578
# New batch
# tensor(0.5385, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4608898162841797
# Time loading: 0.0002009868621826172
# New batch
# tensor(0.4674, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4592604637145996
# Time loading: 0.0008497238159179688
# New batch
# tensor(0.5404, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4579184055328369
# Time loading: 0.005781412124633789
# New batch
# tensor(0.4625, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4601109027862549
# Time loading: 0.00032711029052734375
# New batch
# tensor(0.7741, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46154308319091797
# Time loading: 0.0020079612731933594
# New batch
# tensor(0.4031, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45593786239624023
# Time loading: 0.0008590221405029297
# New batch
# tensor(0.4723, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45811033248901367
# Time loading: 1.9821200370788574
# New batch
# tensor(0.3712, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5622131824493408
# Time loading: 0.0003387928009033203
# New batch
# tensor(0.3565, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.48621582984924316
# Time loading: 0.00028967857360839844
# New batch
# tensor(0.4519, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46071839332580566
# Time loading: 0.0001926422119140625
# New batch
# tensor(0.5052, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4631645679473877
# Time loading: 2.6430485248565674
# New batch
# tensor(0.3423, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5212669372558594
# Time loading: 3.557528495788574
# New batch
# tensor(0.4511, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5105013847351074
# Time loading: 0.0009121894836425781
# New batch
# tensor(0.4032, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4720275402069092
# Time loading: 0.0009124279022216797
# New batch
# tensor(0.6047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4600660800933838
# Time loading: 0.00029349327087402344
# New batch
# tensor(0.5037, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4689140319824219
# Time loading: 0.00028133392333984375
# New batch
# tensor(0.2932, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.47611212730407715
# Time loading: 0.0007085800170898438
# New batch
# tensor(0.3097, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46950840950012207
# Time loading: 0.0021584033966064453
# New batch
# tensor(0.2948, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46329402923583984
# Time loading: 0.001508474349975586
# New batch
# tensor(0.4763, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46250081062316895
# Time loading: 0.00028777122497558594
# New batch
# tensor(0.5646, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46361422538757324
# Time loading: 0.003122091293334961
# New batch
# tensor(0.5185, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.49277710914611816
# Time loading: 0.0007724761962890625
# New batch
# tensor(0.4193, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4608280658721924
# Time loading: 0.10103225708007812
# New batch
# tensor(0.4068, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46048736572265625
# Time loading: 0.0012607574462890625
# New batch
# tensor(0.2517, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4656815528869629
# Time loading: 0.0031244754791259766
# New batch
# tensor(0.3927, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4689350128173828
# Time loading: 0.0010149478912353516
# New batch
# tensor(0.4047, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46140480041503906
# Time loading: 6.911894083023071
# New batch
# tensor(0.3367, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5101094245910645
# Time loading: 4.032428503036499
# New batch
# tensor(0.4521, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.5332643985748291
# Time loading: 0.0007352828979492188
# New batch
# tensor(0.3496, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.46002697944641113
# Time loading: 0.0011167526245117188
# New batch
# tensor(0.4656, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4829409122467041
# Time loading: 0.0009937286376953125
# New batch
# tensor(0.4396, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45796656608581543
# Time loading: 0.0006771087646484375
# New batch
# tensor(0.4437, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4581639766693115
# Time loading: 0.0009629726409912109
# New batch
# tensor(0.5059, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.4596085548400879
# Time loading: 0.0006909370422363281
# New batch
# tensor(0.4379, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45691919326782227
# Time loading: 0.0003933906555175781
# New batch
# tensor(0.3862, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# Time executing: 0.45916295051574707
# Time loading: 0.0007066726684570312
# New batch
# tensor(0.3662, device='cuda:0', grad_fn=<BinaryCrossEntropyWithLogitsBackward>)

# %% [markdown]
# # Saving model

# %%
torch.save(model_conv, "model.pt")

# %% [markdown]
# # Sandbox

# %%
import multiprocessing

multiprocessing.cpu_count()
# Out:
# 2

# %%
batch_size = 32
#[test_dataloader[i:i+batch_size] for i in range(0, len(test_dataloader), batch_size)])
np.array(test_dataloader[0:10]).shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-450d82cfbd4e> in <module>()
#       1 batch_size = 32
#       2 #[test_dataloader[i:i+batch_size] for i in range(0, len(test_dataloader), batch_size)])
# ----> 3 np.array(test_dataloader[0:10]).shape
#
# TypeError: 'DataLoader' object is not subscriptable
